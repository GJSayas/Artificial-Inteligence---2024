# %% [markdown]
# # <font style="color:blue"> Face Mask Detector - YOLO v3 - Linux</font>
# -This notebook currently doesn't show predictions, I'm are woorking on it!
#                       ~G. Sayas

# %%
import random
import os
import subprocess
import sys
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

from google.colab import drive
from datetime import datetime

# %matplotlib inline

# %% [markdown]
# ### <font color="pink">0.  Verification of the GPU </font>
# Just seeing which GPU on the cloud with colab.

# %%
#Test to see if we are using the GPU
if 'GPU:0' in tf.test.gpu_device_name():
  print("Yeah, We are using the GPU!")
else:
  print("No GPU Allocated")
# Out:
# Yeah, We are using the GPU!

# %%
#Which type of GPU?
# !nvidia-smi
# Out:
# Sat Apr 20 23:18:49 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0              26W /  70W |    103MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ### <font color="pink">1.  Load Google Drive</font>
# We will load our google drive space to simplify the process

# %%
drive.mount('/content/drive')
# !rm -rf /content/drive/My\ Drive/YOLO # clean install if exists
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### <font color="pink">2.  Change to the Drive space</font>
# Now we will be inside our drive to allocate the files and also create a folder specifically to YOLO V3.

# %%
# %cd /content/drive/My\ Drive
# %mkdir YOLO
# Out:
# /content/drive/My Drive

# %% [markdown]
# ### <font color="pink">3.  Download Alexey AB YOLO repository to our google drive *yolov3* folder</font>
# We now will download the well maintained repository of a YOLO expert, because Joseph Redmon will not continue working on YOLO. :/

# %%
# %cd /content/drive/My\ Drive/YOLO
# !rm -rf darknet # clean folder if exists, sometimes when reconnecting gives error about permissions
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# /content/drive/My Drive/YOLO
# Cloning into 'darknet'...
# remote: Enumerating objects: 15833, done.
# remote: Total 15833 (delta 0), reused 0 (delta 0), pack-reused 15833
# Receiving objects: 100% (15833/15833), 14.39 MiB | 13.12 MiB/s, done.
# Resolving deltas: 100% (10666/10666), done.
# Updating files: 100% (2056/2056), done.

# %% [markdown]
# ### <font color="pink">4.  Compile Darknet</font>
# Modify some strings on the makefile to compile darknet.

# %%
# %cd /content/drive/My\ Drive/YOLO/darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

print("[INFO] - Building Darknet, this will take a few minutes. Get a coffee!")

# !make &> build_log.txt

print("[INFO] - Build Finished!")
# Out:
# /content/drive/My Drive/YOLO/darknet
# [INFO] - Building Darknet, this will take a few minutes. Get a coffee!
# [INFO] - Build Finished!

# %% [markdown]
# ### <font color="pink">5.  Download the *Mask / No Mask Dataset*</font>
# Download the curated dataset of face mask and not facemask to our dataset folder, but first lets create a dataset folder.

# %%
# %cd /content/drive/My\ Drive/YOLO
# %mkdir dataset
# Out:
# /content/drive/My Drive/YOLO

# %%
# %cd /content/drive/My\ Drive/YOLO/dataset
# !wget https://www.dropbox.com/s/6gewe947ake1g95/kaggle_and_no-mask_dataset.zip
# !unzip kaggle_and_no-mask_dataset.zip &> /dev/null
# !rm -rf kaggle_and_no-mask_dataset.zip
# !rm -rf .ipynb_checkpoints/
# Out:
# /content/drive/My Drive/YOLO/dataset
# --2024-04-20 23:26:40--  https://www.dropbox.com/s/6gewe947ake1g95/kaggle_and_no-mask_dataset.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /scl/fi/lb13hhxkb8f8aubo6g8w1/kaggle_and_no-mask_dataset.zip?rlkey=5lf2oh8n948md7w1d5a25i26p [following]
# --2024-04-20 23:26:40--  https://www.dropbox.com/scl/fi/lb13hhxkb8f8aubo6g8w1/kaggle_and_no-mask_dataset.zip?rlkey=5lf2oh8n948md7w1d5a25i26p
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucfeb2d631450a584c7fdff4f3d7.dl.dropboxusercontent.com/cd/0/inline/CRZZVhXpWMppBVg6FkNQ4ckK9kcnfT3kiSjbMGQQqrY00b9I9qUVWbbtz-YiOKfZucF-C5wEesvXEMxQ4Bydv7Pg24WCDBXL046l71ysZ4NoyVqcidBUwAiz-KNtcwSgniBvHGxeIQByVXlB-OSSafk_/file# [following]
# --2024-04-20 23:26:41--  https://ucfeb2d631450a584c7fdff4f3d7.dl.dropboxusercontent.com/cd/0/inline/CRZZVhXpWMppBVg6FkNQ4ckK9kcnfT3kiSjbMGQQqrY00b9I9qUVWbbtz-YiOKfZucF-C5wEesvXEMxQ4Bydv7Pg24WCDBXL046l71ysZ4NoyVqcidBUwAiz-KNtcwSgniBvHGxeIQByVXlB-OSSafk_/file
# Resolving ucfeb2d631450a584c7fdff4f3d7.dl.dropboxusercontent.com (ucfeb2d631450a584c7fdff4f3d7.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to ucfeb2d631450a584c7fdff4f3d7.dl.dropboxusercontent.com (ucfeb2d631450a584c7fdff4f3d7.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CRbzAhw-k3uBQ1S4IsJKxx3UjYn8OFEyO7YMmm2UgJrer2Cr8svJKkD74CGwNEoKfDdhTeya3wmvaxpaJyaHvi1AesMcutIOdFGj0oLaPcE_wVgTiCu9Wp9IKhlHtIDGQlAO31gjkZKRz95fsp9fRivWX-tnS9H6Dc8E8neyToFPzqQ1HutkRQiXLVVIjRdiwQL0dNGC-jiO9DCyWSr3d4rA8gCK3wO2P7EfuHGOQ3yQ9JHMJ_AJzpxUoO8MbGxwu2qL5VRNJuBrNDhkDEsY4EcOLRyXS30UEz-LrkSpMRZktvewbCTr-bHE0E0LJTkvRQoVkwuIZBDhcVCpYfsSRBTfNOIHr6n4WkQ3rdQcbNbpTkjTT2KGWmCh4O63qSLc8dU/file [following]
# --2024-04-20 23:26:42--  https://ucfeb2d631450a584c7fdff4f3d7.dl.dropboxusercontent.com/cd/0/inline2/CRbzAhw-k3uBQ1S4IsJKxx3UjYn8OFEyO7YMmm2UgJrer2Cr8svJKkD74CGwNEoKfDdhTeya3wmvaxpaJyaHvi1AesMcutIOdFGj0oLaPcE_wVgTiCu9Wp9IKhlHtIDGQlAO31gjkZKRz95fsp9fRivWX-tnS9H6Dc8E8neyToFPzqQ1HutkRQiXLVVIjRdiwQL0dNGC-jiO9DCyWSr3d4rA8gCK3wO2P7EfuHGOQ3yQ9JHMJ_AJzpxUoO8MbGxwu2qL5VRNJuBrNDhkDEsY4EcOLRyXS30UEz-LrkSpMRZktvewbCTr-bHE0E0LJTkvRQoVkwuIZBDhcVCpYfsSRBTfNOIHr6n4WkQ3rdQcbNbpTkjTT2KGWmCh4O63qSLc8dU/file
# Reusing existing connection to ucfeb2d631450a584c7fdff4f3d7.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 225596705 (215M) [application/zip]
# Saving to: ‘kaggle_and_no-mask_dataset.zip’
#
# kaggle_and_no-mask_ 100%[===================>] 215.15M  37.9MB/s    in 5.8s
#
# 2024-04-20 23:26:48 (37.4 MB/s) - ‘kaggle_and_no-mask_dataset.zip’ saved [225596705/225596705]

# %% [markdown]
# ### <font color="pink">6.  Prepare the Train and Test Files</font>
# This code provided creates two files, one for the training images and other for the test images.
#
# The dataset is divided in:
# - 80% training set
# - 20% test set

# %%
# %cd /content/drive/My Drive/YOLO

image_dir = "./dataset"
f_val = open("DS_test.txt", 'w')
f_train = open("DS_train.txt", 'w')

path, dirs, files = next(os.walk(image_dir))
data_size = len(files)

ind = 0
data_test_size = int(0.2 * data_size)
test_array = random.sample(range(data_size), k=data_test_size)

for f in os.listdir(image_dir):
    if(f.split(".")[-1] == "jpg"):
        ind += 1

        if ind in test_array:
            f_val.write(image_dir+'/'+f+'\n')
        else:
            f_train.write(image_dir+'/'+f+'\n')

f_train.close()
f_val.close()
# Out:
# /content/drive/My Drive/YOLO

# %% [markdown]
# ### <font color="pink">7.  Prepare and Upload the configuration files</font>
#
# For train and use yolo we need to prepare the neccesary files, finally we will upload to our yolov3 folder:  **`yolov3-mask_nomask-setup.data`**,  **`yolov3-mask_nomask-train.cfg`** (based on the default file of darknet folder over the VOC dataset, yolov3-voc.cfg)... Width, Height, Channels, Momentum and Decay, Learning Rate, Steps, Scales, Burn In (warm-up), Data augmentation, Number of iterations, Change filters parameter & **`yolov3.names`** file.

# %% [markdown]
# ### <font color="pink">8. Cloning the configuration Repository</font>
# This repository is prepared with the desired configuration for yolov3 and yolov4.
#
# In this case we will be using yolo v3.  The structure of the folder (for yolo v3 only for simplicity) is as follows:
#
# ```
# /FacialMaskDetector
# ├── test
# │   ├── test-image1.jpg
# │   ├── test-image2.jpg
# │   ├── test-image3.jpg
# │   ├── test-image4.jpg
# │   ├── test-video1.jpg
# │   ├── test-video2.jpg
# ├── yolov3
# │       ├── backup
# │       │   ├── README.md
# │       ├── config
# │           ├── yolov3-mask_nomask-setup.data
# │           ├── yolov3-mask_nomask-test.cfg
# │           ├── yolov3-mask_nomask-train.cfg
# │           ├── yolov3.names
# │       ├── weights
# │           ├── README.md
# ├── README.md
# ```
#
# This will ease for us the way of training and inference.

# %%
# %cd /content/drive/My Drive/YOLO
# !git clone https://github.com/issaiass/FacialMaskDetector.git
# Out:
# /content/drive/My Drive/YOLO
# Cloning into 'FacialMaskDetector'...
# remote: Enumerating objects: 116, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 116 (delta 21), reused 37 (delta 11), pack-reused 67
# Receiving objects: 100% (116/116), 68.51 MiB | 18.51 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# Updating files: 100% (25/25), done.

# %% [markdown]
# ### <font color="pink">9. Cloning the Weights</font>
# We will be doing fine-tuning, so we need to download the actual pre-trained weights.

# %%
# %cd /content/drive/My\ Drive/YOLO/FacialMaskDetector/yolov3/weights

# Original File : https://pjreddie.com/media/files/darknet53.conv.74
# !wget "https://www.dropbox.com/s/18dwbfth7prbf0h/darknet53.conv.74?dl=1" -O darknet53.conv.74
# Out:
# /content/drive/My Drive/YOLO/FacialMaskDetector/yolov3/weights
# --2024-04-20 23:27:50--  https://www.dropbox.com/s/18dwbfth7prbf0h/darknet53.conv.74?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.71.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.71.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /scl/fi/cte4fqetysju1dsccfjco/darknet53.conv.74?rlkey=bluydjd10mna3w539cuyrqf6n&dl=1 [following]
# --2024-04-20 23:27:51--  https://www.dropbox.com/scl/fi/cte4fqetysju1dsccfjco/darknet53.conv.74?rlkey=bluydjd10mna3w539cuyrqf6n&dl=1
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc491cef798fcf9179ff178fab1e.dl.dropboxusercontent.com/cd/0/inline/CRYu7bXy7H5QcoU_i_Xgv6P1c2y1IfOFvU-phWtuUjmgaE_Xaci7vwvhF38eReNz0uQwsqCX4DBx23Ecl-gJj4Z_anuNqVr2ceO9NO0XOiRlOhPpb3bO8kWVUd5luNwmyuif-olHqWQ2HuyOCBTsmPnO/file?dl=1# [following]
# --2024-04-20 23:27:52--  https://uc491cef798fcf9179ff178fab1e.dl.dropboxusercontent.com/cd/0/inline/CRYu7bXy7H5QcoU_i_Xgv6P1c2y1IfOFvU-phWtuUjmgaE_Xaci7vwvhF38eReNz0uQwsqCX4DBx23Ecl-gJj4Z_anuNqVr2ceO9NO0XOiRlOhPpb3bO8kWVUd5luNwmyuif-olHqWQ2HuyOCBTsmPnO/file?dl=1
# Resolving uc491cef798fcf9179ff178fab1e.dl.dropboxusercontent.com (uc491cef798fcf9179ff178fab1e.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to uc491cef798fcf9179ff178fab1e.dl.dropboxusercontent.com (uc491cef798fcf9179ff178fab1e.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CRbh0VAv2cqvz6Ng1sHeQEyjyFRhSdAcO2_rkSf34mJO-_8zFmRe__u60Q7LPqCKAGGzSOaR3o_8zje4yQSVWQLidBvkoz2xyyr3oMh8iIgARvHRTDxFGQLRgadEFbDlsmSAqLIJB9ZIPiOlNP2orGWkj34RGNCzN8gjmjxjkO4DmZ9m_nAfAsfmNlb5fQp0i3iJdelyq8vCa9hWUhWFqb2w2aRqLfOOW1bLyb2pUlNRUg3P4EIivXYJPxqiW3HYePT9WSD29LGe6Labht3CZXCq2sOSvDrItdfyuSjf86GdZUB4fHOt9U1k9fhfCOwXLzJdlWODX6uP49Dkq7LCZk8OzEBYpJVMs6sEYCmYWEPtTz-uKZnW9gpn9o1_UcUmAdU/file?dl=1 [following]
# --2024-04-20 23:27:52--  https://uc491cef798fcf9179ff178fab1e.dl.dropboxusercontent.com/cd/0/inline2/CRbh0VAv2cqvz6Ng1sHeQEyjyFRhSdAcO2_rkSf34mJO-_8zFmRe__u60Q7LPqCKAGGzSOaR3o_8zje4yQSVWQLidBvkoz2xyyr3oMh8iIgARvHRTDxFGQLRgadEFbDlsmSAqLIJB9ZIPiOlNP2orGWkj34RGNCzN8gjmjxjkO4DmZ9m_nAfAsfmNlb5fQp0i3iJdelyq8vCa9hWUhWFqb2w2aRqLfOOW1bLyb2pUlNRUg3P4EIivXYJPxqiW3HYePT9WSD29LGe6Labht3CZXCq2sOSvDrItdfyuSjf86GdZUB4fHOt9U1k9fhfCOwXLzJdlWODX6uP49Dkq7LCZk8OzEBYpJVMs6sEYCmYWEPtTz-uKZnW9gpn9o1_UcUmAdU/file?dl=1
# Reusing existing connection to uc491cef798fcf9179ff178fab1e.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/binary]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  29.4MB/s    in 5.3s
#
# 2024-04-20 23:27:58 (29.1 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# ### <font color="pink">10. Copy Labels Folder </font>
#
# First we did a first step that is to copy the data folder of darknet to the root, because inside are the labels to graph the letters and numbers.  If this step is omited you will see a black box and no inference name.

# %%
# %cd /content/drive/My\ Drive/YOLO
# !mkdir data
# !cp -R darknet/data/* ./data
# Out:
# /content/drive/My Drive/YOLO

# %% [markdown]
# ### <font color="pink">11. Review Hyperparameters</font>
#
# If you want to change some hyperparameters this is a good way to do it.
# Finally, always check your changes.

# %%
# this is for using as arguments of the terminal
yolo_setup        = 'FacialMaskDetector\/yolov3\/config\/yolov3-mask_nomask-setup.data'
yolo_train        = 'FacialMaskDetector\/yolov3\/config\/yolov3-mask_nomask-train.cfg'
yolo_test         = 'FacialMaskDetector\/yolov3\/config\/yolov3-mask_nomask-test.cfg'
yolo_weights      = 'FacialMaskDetector\/yolov3\/weights\/darknet53.conv.74'
yolo_best_weights = 'FacialMaskDetector\/yolov3\/backup\/yolov3-mask_nomask-train_best.weights'
yolo_test_path    = 'FacialMaskDetector\/test'

# %%
# %cd /content/drive/My\ Drive/YOLO

#An example for changing specific lines in a file
#!sed -i 's/batch=32/batch=16/' $yolo_train
#!sed -i 's/subdivisions=16/subdivisions=8/' $yolo_train
#!sed -i 's/width=416/width=512/' $yolo_train
#!sed -i 's/height=416/height=512/' $yolo_train
#!sed -i 's/learning_rate=0.001/learning_rate=0.001/' $yolo_train
#!sed -i 's/burn_in=600/burn_in=1000/' $yolo_train
#!sed -i 's/max_batches=6000/max_batches=10000/' $yolo_train
#!sed -i 's/steps=4200,4800,5400/steps=7000,8000,9000/' $yolo_train
#!sed -i 's/scales=.1,.1,.1,.1/scales=.1,.1,.1/' $yolo_train

#Check if the configuration of hyperparameter is ok
# !head -25 FacialMaskDetector/yolov3/config/yolov3-mask_nomask-train.cfg
# Out:
# /content/drive/My Drive/YOLO
# # Based on cfg/yolov3-voc.cfg
#
# [net]
# # Testing
# # batch=1
# # subdivisions=1
# # Training
# batch=16
# subdivisions=8
# width=512
# height=512
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.001
# burn_in=1000
# max_batches=10000
# policy=steps
# steps=7000,8000,9000
# scales=.1,.1,.1

# %% [markdown]
# ### <font color="pink">12. Let's do some Training! </font>
#
# We need to pass the training files for the darknet framework to start the process.
#
# Remember!, we need to specify the complete paths of these files that we talked before:
# 1. setup file,
# 1. config file,
# 1. convolutional weights file
#
# There are a few flags like **`dont_show`** which wont display the graphs and **`map`** - for the mAP calculation over the DS_test.txt file (20% of our data).

# %%
# %cd /content/drive/My\ Drive/YOLO
#!chmod 777 /content/drive/My\ Drive/YOLO/darknet/darknet
# !./darknet/darknet detector train  $yolo_setup $yolo_train $yolo_weights -dont_show -map 2> train_log.txt
# Out:
# /content/drive/My Drive/YOLO
#  Prepare additional network for mAP calculation...
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# yolov3-mask_nomask-train
# net.optimized_memory = 0
# mini_batch = 2, batch = 16, time_steps = 1, train = 1
#
#  seen 64, trained: 0 K-images (0 Kilo-batches_64)
# Weights are saved after: 10000 iterations. Last weights (*_last.weight) are stored every 100 iterations.
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# Resizing, random_coef = 1.40
#
#  736 x 736
#  try to allocate additional workspace_size = 238.73 MB
#  CUDA allocate done!
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 1000 iterations) 1/10000: loss=10247.4 hours left=-1.0
#  1: 10247.369141, 10247.369141 avg loss, 0.000000 rate, 6.559004 seconds, 16 images, -1.000000 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 2/10000: loss=10267.6 hours left=18.2
#  2: 10267.556641, 10249.387695 avg loss, 0.000000 rate, 3.650390 seconds, 32 images, 18.217836 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 3/10000: loss=10263.8 hours left=18.1
#  3: 10263.823242, 10250.831055 avg loss, 0.000000 rate, 3.626734 seconds, 48 images, 18.137039 hours left
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 1000 iterations) 4/10000: loss=10260.5 hours left=18.1
#  4: 10260.513672, 10251.798828 avg loss, 0.000000 rate, 3.962410 seconds, 64 images, 18.056382 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 5/10000: loss=10263.4 hours left=18.0
#  5: 10263.351562, 10252.954102 avg loss, 0.000000 rate, 3.585203 seconds, 80 images, 17.985844 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 6/10000: loss=10260.0 hours left=17.9
#  6: 10260.015625, 10253.660156 avg loss, 0.000000 rate, 3.656202 seconds, 96 images, 17.905526 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 7/10000: loss=10263.5 hours left=17.8
#  7: 10263.485352, 10254.642578 avg loss, 0.000000 rate, 3.801224 seconds, 112 images, 17.827973 hours left
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 1000 iterations) 8/10000: loss=10238.4 hours left=17.8
#  8: 10238.416992, 10253.019531 avg loss, 0.000000 rate, 3.634676 seconds, 128 images, 17.755210 hours left
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 1000 iterations) 9/10000: loss=10244.4 hours left=17.7
#  9: 10244.353516, 10252.153320 avg loss, 0.000000 rate, 3.630874 seconds, 144 images, 17.678543 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 10/10000: loss=10246.6 hours left=17.6
#  10: 10246.644531, 10251.602539 avg loss, 0.000000 rate, 3.715438 seconds, 160 images, 17.602526 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 164.41 MB
#  CUDA allocate done!
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 11/10000: loss=7011.0 hours left=17.5
#  11: 7011.016602, 9927.543945 avg loss, 0.000000 rate, 2.656257 seconds, 176 images, 17.529606 hours left
# Loaded: 0.000058 seconds
#
#  (next mAP calculation at 1000 iterations) 12/10000: loss=6998.6 hours left=17.4
#  12: 6998.631836, 9634.652344 avg loss, 0.000000 rate, 2.761363 seconds, 192 images, 17.428016 hours left
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 1000 iterations) 13/10000: loss=6999.9 hours left=17.3
#  13: 6999.861328, 9371.172852 avg loss, 0.000000 rate, 2.732351 seconds, 208 images, 17.330350 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 14/10000: loss=6989.8 hours left=17.2
#  14: 6989.812500, 9133.037109 avg loss, 0.000000 rate, 2.731706 seconds, 224 images, 17.232848 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 15/10000: loss=7005.2 hours left=17.1
#  15: 7005.202637, 8920.253906 avg loss, 0.000000 rate, 3.156187 seconds, 240 images, 17.136296 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 16/10000: loss=7005.6 hours left=17.1
#  16: 7005.582031, 8728.787109 avg loss, 0.000000 rate, 2.767861 seconds, 256 images, 17.052475 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 17/10000: loss=7003.8 hours left=17.0
#  17: 7003.782227, 8556.287109 avg loss, 0.000000 rate, 2.761520 seconds, 272 images, 16.958714 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 1000 iterations) 18/10000: loss=7008.1 hours left=16.9
#  18: 7008.062500, 8401.464844 avg loss, 0.000000 rate, 2.776302 seconds, 288 images, 16.865707 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 1000 iterations) 19/10000: loss=6996.6 hours left=16.8
#  19: 6996.576660, 8260.975586 avg loss, 0.000000 rate, 3.123827 seconds, 304 images, 16.774033 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 20/10000: loss=6983.7 hours left=16.7
#  20: 6983.725586, 8133.250488 avg loss, 0.000000 rate, 2.830930 seconds, 320 images, 16.692903 hours left
# Resizing, random_coef = 1.40
#
#  480 x 480
#  try to allocate additional workspace_size = 104.25 MB
#  CUDA allocate done!
# Loaded: 0.000063 seconds
#
#  (next mAP calculation at 1000 iterations) 21/10000: loss=4365.4 hours left=16.6
#  21: 4365.359375, 7756.461426 avg loss, 0.000000 rate, 1.643466 seconds, 336 images, 16.604455 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 22/10000: loss=4364.6 hours left=16.5
#  22: 4364.573242, 7417.272461 avg loss, 0.000000 rate, 1.841716 seconds, 352 images, 16.483969 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 1000 iterations) 23/10000: loss=4349.3 hours left=16.4
#  23: 4349.265625, 7110.471680 avg loss, 0.000000 rate, 1.737085 seconds, 368 images, 16.370177 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 24/10000: loss=4355.3 hours left=16.3
#  24: 4355.305176, 6834.955078 avg loss, 0.000000 rate, 1.755010 seconds, 384 images, 16.254618 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 1000 iterations) 25/10000: loss=4349.9 hours left=16.1
#  25: 4349.854004, 6586.444824 avg loss, 0.000000 rate, 1.846249 seconds, 400 images, 16.140707 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 26/10000: loss=4346.3 hours left=16.0
#  26: 4346.325195, 6362.432617 avg loss, 0.000000 rate, 1.981277 seconds, 416 images, 16.030458 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 27/10000: loss=4337.7 hours left=15.9
#  27: 4337.652344, 6159.954590 avg loss, 0.000000 rate, 1.760822 seconds, 432 images, 15.925047 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations) 28/10000: loss=4329.3 hours left=15.8
#  28: 4329.278320, 5976.886719 avg loss, 0.000000 rate, 1.695053 seconds, 448 images, 15.814578 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 29/10000: loss=4323.3 hours left=15.7
#  29: 4323.264648, 5811.524414 avg loss, 0.000000 rate, 1.752964 seconds, 464 images, 15.703387 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 30/10000: loss=4322.7 hours left=15.6
#  30: 4322.654297, 5662.637207 avg loss, 0.000000 rate, 1.805593 seconds, 480 images, 15.594907 hours left
# Resizing, random_coef = 1.40
#
#  672 x 672
#  try to allocate additional workspace_size = 199.80 MB
#  CUDA allocate done!
# Loaded: 0.000072 seconds
#
#  (next mAP calculation at 1000 iterations) 31/10000: loss=8455.1 hours left=15.5
#  31: 8455.143555, 5941.887695 avg loss, 0.000000 rate, 3.581538 seconds, 496 images, 15.488964 hours left
# Loaded: 0.000086 seconds
#
#  (next mAP calculation at 1000 iterations) 32/10000: loss=8424.1 hours left=15.4
#  32: 8424.054688, 6190.104492 avg loss, 0.000000 rate, 3.386962 seconds, 512 images, 15.433256 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 1000 iterations) 33/10000: loss=8398.8 hours left=15.4
#  33: 8398.801758, 6410.974121 avg loss, 0.000000 rate, 3.299864 seconds, 528 images, 15.372707 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 34/10000: loss=8383.9 hours left=15.3
#  34: 8383.863281, 6608.263184 avg loss, 0.000000 rate, 3.440958 seconds, 544 images, 15.310343 hours left
# Loaded: 0.000064 seconds
#
#  (next mAP calculation at 1000 iterations) 35/10000: loss=8346.4 hours left=15.3
#  35: 8346.369141, 6782.073730 avg loss, 0.000000 rate, 3.661934 seconds, 560 images, 15.252498 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 36/10000: loss=8307.8 hours left=15.2
#  36: 8307.849609, 6934.651367 avg loss, 0.000000 rate, 3.429623 seconds, 576 images, 15.201340 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 37/10000: loss=8266.5 hours left=15.1
#  37: 8266.547852, 7067.840820 avg loss, 0.000000 rate, 3.352485 seconds, 592 images, 15.144253 hours left
# Loaded: 0.000071 seconds
#
#  (next mAP calculation at 1000 iterations) 38/10000: loss=8231.5 hours left=15.1
#  38: 8231.485352, 7184.205078 avg loss, 0.000000 rate, 4.019239 seconds, 608 images, 15.085592 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 1000 iterations) 39/10000: loss=8167.6 hours left=15.0
#  39: 8167.593750, 7282.543945 avg loss, 0.000000 rate, 3.242153 seconds, 624 images, 15.045960 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations) 40/10000: loss=8114.0 hours left=15.0
#  40: 8113.971191, 7365.686523 avg loss, 0.000000 rate, 3.311368 seconds, 640 images, 14.985211 hours left
# Resizing, random_coef = 1.40
#
#  736 x 736
#  try to allocate additional workspace_size = 238.73 MB
#  CUDA allocate done!
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 41/10000: loss=9645.8 hours left=14.9
#  41: 9645.826172, 7593.700684 avg loss, 0.000000 rate, 3.949748 seconds, 656 images, 14.926975 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 42/10000: loss=9545.2 hours left=14.9
#  42: 9545.226562, 7788.853516 avg loss, 0.000000 rate, 3.963756 seconds, 672 images, 14.886973 hours left
# Loaded: 0.000069 seconds
#
#  (next mAP calculation at 1000 iterations) 43/10000: loss=9455.7 hours left=14.8
#  43: 9455.729492, 7955.541016 avg loss, 0.000000 rate, 3.948255 seconds, 688 images, 14.847747 hours left
# Loaded: 0.000076 seconds
#
#  (next mAP calculation at 1000 iterations) 44/10000: loss=9336.5 hours left=14.8
#  44: 9336.463867, 8093.633301 avg loss, 0.000000 rate, 3.986171 seconds, 704 images, 14.808474 hours left
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 1000 iterations) 45/10000: loss=9212.6 hours left=14.8
#  45: 9212.621094, 8205.532227 avg loss, 0.000000 rate, 4.244288 seconds, 720 images, 14.770632 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 1000 iterations) 46/10000: loss=9072.3 hours left=14.7
#  46: 9072.293945, 8292.208008 avg loss, 0.000000 rate, 3.782870 seconds, 736 images, 14.740294 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 1000 iterations) 47/10000: loss=8920.2 hours left=14.7
#  47: 8920.240234, 8355.011719 avg loss, 0.000000 rate, 4.071740 seconds, 752 images, 14.697489 hours left
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 1000 iterations) 48/10000: loss=8753.6 hours left=14.7
#  48: 8753.577148, 8394.868164 avg loss, 0.000000 rate, 4.398956 seconds, 768 images, 14.663089 hours left
# Loaded: 0.000063 seconds
#
#  (next mAP calculation at 1000 iterations) 49/10000: loss=8564.2 hours left=14.6
#  49: 8564.184570, 8411.799805 avg loss, 0.000000 rate, 3.871537 seconds, 784 images, 14.638067 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 50/10000: loss=8377.1 hours left=14.6
#  50: 8377.102539, 8408.330078 avg loss, 0.000000 rate, 4.034265 seconds, 800 images, 14.598704 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 79.48 MB
#  CUDA allocate done!
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations) 51/10000: loss=2617.7 hours left=14.6
#  51: 2617.692871, 7829.266602 avg loss, 0.000000 rate, 1.622097 seconds, 816 images, 14.564221 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 52/10000: loss=2536.9 hours left=14.5
#  52: 2536.855225, 7300.025391 avg loss, 0.000000 rate, 1.495966 seconds, 832 images, 14.463409 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 53/10000: loss=2478.7 hours left=14.4
#  53: 2478.716553, 6817.894531 avg loss, 0.000000 rate, 1.490051 seconds, 848 images, 14.360116 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 54/10000: loss=2415.1 hours left=14.3
#  54: 2415.089111, 6377.613770 avg loss, 0.000000 rate, 1.521682 seconds, 864 images, 14.257687 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 55/10000: loss=2339.6 hours left=14.2
#  55: 2339.632812, 5973.815918 avg loss, 0.000000 rate, 1.452608 seconds, 880 images, 14.157153 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 56/10000: loss=2275.2 hours left=14.1
#  56: 2275.220459, 5603.956543 avg loss, 0.000000 rate, 1.477628 seconds, 896 images, 14.055711 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 1000 iterations) 57/10000: loss=2201.7 hours left=14.0
#  57: 2201.742676, 5263.735352 avg loss, 0.000000 rate, 1.442636 seconds, 912 images, 13.955971 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 1000 iterations) 58/10000: loss=2167.0 hours left=13.9
#  58: 2167.044434, 4954.066406 avg loss, 0.000000 rate, 1.701076 seconds, 928 images, 13.856257 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 59/10000: loss=2088.0 hours left=13.8
#  59: 2088.032227, 4667.462891 avg loss, 0.000000 rate, 1.594617 seconds, 944 images, 13.764674 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 60/10000: loss=2022.7 hours left=13.7
#  60: 2022.736328, 4402.990234 avg loss, 0.000000 rate, 1.545798 seconds, 960 images, 13.671063 hours left
# Resizing, random_coef = 1.40
#
#  672 x 672
#  try to allocate additional workspace_size = 199.80 MB
#  CUDA allocate done!
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 61/10000: loss=5094.7 hours left=13.6
#  61: 5094.682617, 4472.159668 avg loss, 0.000000 rate, 3.238006 seconds, 976 images, 13.577035 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations) 62/10000: loss=4972.6 hours left=13.5
#  62: 4972.606934, 4522.204590 avg loss, 0.000000 rate, 3.291776 seconds, 992 images, 13.530662 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 63/10000: loss=4728.0 hours left=13.5
#  63: 4728.022461, 4542.786133 avg loss, 0.000000 rate, 3.392210 seconds, 1008 images, 13.486229 hours left
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 1000 iterations) 64/10000: loss=4566.2 hours left=13.4
#  64: 4566.186523, 4545.125977 avg loss, 0.000000 rate, 3.643907 seconds, 1024 images, 13.445003 hours left
# Loaded: 0.000065 seconds
#
#  (next mAP calculation at 1000 iterations) 65/10000: loss=4350.8 hours left=13.4
#  65: 4350.752930, 4525.688477 avg loss, 0.000000 rate, 3.334329 seconds, 1040 images, 13.411127 hours left
# Loaded: 0.000058 seconds
#
#  (next mAP calculation at 1000 iterations) 66/10000: loss=4122.6 hours left=13.4
#  66: 4122.582031, 4485.377930 avg loss, 0.000000 rate, 3.331175 seconds, 1056 images, 13.369036 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 67/10000: loss=3930.1 hours left=13.3
#  67: 3930.078125, 4429.848145 avg loss, 0.000000 rate, 3.587524 seconds, 1072 images, 13.327269 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 68/10000: loss=3702.4 hours left=13.3
#  68: 3702.352295, 4357.098633 avg loss, 0.000000 rate, 3.419761 seconds, 1088 images, 13.292984 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 69/10000: loss=3481.0 hours left=13.3
#  69: 3481.023926, 4269.491211 avg loss, 0.000000 rate, 3.249415 seconds, 1104 images, 13.254403 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 70/10000: loss=3241.7 hours left=13.2
#  70: 3241.699951, 4166.711914 avg loss, 0.000000 rate, 3.366156 seconds, 1120 images, 13.211500 hours left
# Resizing, random_coef = 1.40
#
#  736 x 736
#  try to allocate additional workspace_size = 238.73 MB
#  CUDA allocate done!
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 71/10000: loss=3643.2 hours left=13.2
#  71: 3643.158447, 4114.356445 avg loss, 0.000000 rate, 3.850973 seconds, 1136 images, 13.172236 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 72/10000: loss=3402.8 hours left=13.1
#  72: 3402.786865, 4043.199463 avg loss, 0.000000 rate, 3.792334 seconds, 1152 images, 13.146728 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 73/10000: loss=3092.8 hours left=13.1
#  73: 3092.783203, 3948.157715 avg loss, 0.000000 rate, 4.732472 seconds, 1168 images, 13.119847 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 74/10000: loss=2837.9 hours left=13.1
#  74: 2837.949219, 3837.136963 avg loss, 0.000000 rate, 3.900717 seconds, 1184 images, 13.119148 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 75/10000: loss=2609.0 hours left=13.1
#  75: 2609.016113, 3714.324951 avg loss, 0.000000 rate, 4.458913 seconds, 1200 images, 13.095510 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 76/10000: loss=2357.6 hours left=13.1
#  76: 2357.613525, 3578.653809 avg loss, 0.000000 rate, 4.186941 seconds, 1216 images, 13.087486 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 77/10000: loss=2183.9 hours left=13.1
#  77: 2183.923584, 3439.180664 avg loss, 0.000000 rate, 3.951479 seconds, 1232 images, 13.072033 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 78/10000: loss=1954.7 hours left=13.1
#  78: 1954.711182, 3290.733643 avg loss, 0.000000 rate, 3.929492 seconds, 1248 images, 13.050233 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 79/10000: loss=1770.6 hours left=13.0
#  79: 1770.641479, 3138.724365 avg loss, 0.000000 rate, 3.881738 seconds, 1264 images, 13.028033 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 80/10000: loss=1596.7 hours left=13.0
#  80: 1596.690063, 2984.520996 avg loss, 0.000000 rate, 3.982046 seconds, 1280 images, 13.004729 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 164.41 MB
#  CUDA allocate done!
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 1000 iterations) 81/10000: loss=989.8 hours left=13.0
#  81: 989.770691, 2785.045898 avg loss, 0.000000 rate, 2.647254 seconds, 1296 images, 12.984411 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 82/10000: loss=902.6 hours left=12.9
#  82: 902.579590, 2596.799316 avg loss, 0.000000 rate, 2.961837 seconds, 1312 images, 12.927509 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 83/10000: loss=817.6 hours left=12.9
#  83: 817.613770, 2418.880859 avg loss, 0.000000 rate, 2.925707 seconds, 1328 images, 12.879834 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 84/10000: loss=753.0 hours left=12.8
#  84: 752.994751, 2252.292236 avg loss, 0.000000 rate, 2.849903 seconds, 1344 images, 12.831633 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 85/10000: loss=693.5 hours left=12.8
#  85: 693.481506, 2096.411133 avg loss, 0.000000 rate, 2.860712 seconds, 1360 images, 12.781817 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 86/10000: loss=637.5 hours left=12.7
#  86: 637.490845, 1950.519043 avg loss, 0.000000 rate, 3.036608 seconds, 1376 images, 12.732789 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 87/10000: loss=589.1 hours left=12.7
#  87: 589.144775, 1814.381592 avg loss, 0.000000 rate, 2.766617 seconds, 1392 images, 12.689088 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 1000 iterations) 88/10000: loss=545.2 hours left=12.6
#  88: 545.223022, 1687.465698 avg loss, 0.000000 rate, 3.009284 seconds, 1408 images, 12.638381 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 89/10000: loss=510.4 hours left=12.6
#  89: 510.367096, 1569.755859 avg loss, 0.000000 rate, 2.827832 seconds, 1424 images, 12.594855 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations) 90/10000: loss=478.9 hours left=12.5
#  90: 478.918854, 1460.672119 avg loss, 0.000000 rate, 2.817559 seconds, 1440 images, 12.546760 hours left
# Resizing, random_coef = 1.40
#
#  544 x 544
#  try to allocate additional workspace_size = 132.56 MB
#  CUDA allocate done!
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 1000 iterations) 91/10000: loss=355.7 hours left=12.5
#  91: 355.689117, 1350.173828 avg loss, 0.000000 rate, 2.274804 seconds, 1456 images, 12.498855 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 1000 iterations) 92/10000: loss=342.3 hours left=12.4
#  92: 342.285309, 1249.385010 avg loss, 0.000000 rate, 2.617484 seconds, 1472 images, 12.436482 hours left
# Loaded: 0.000058 seconds
#
#  (next mAP calculation at 1000 iterations) 93/10000: loss=324.9 hours left=12.4
#  93: 324.871399, 1156.933594 avg loss, 0.000000 rate, 2.399058 seconds, 1488 images, 12.384158 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 94/10000: loss=308.6 hours left=12.3
#  94: 308.609161, 1072.101196 avg loss, 0.000000 rate, 2.376484 seconds, 1504 images, 12.326339 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 95/10000: loss=300.6 hours left=12.3
#  95: 300.554535, 994.946533 avg loss, 0.000000 rate, 2.480072 seconds, 1520 images, 12.268470 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 96/10000: loss=275.7 hours left=12.2
#  96: 275.689667, 923.020874 avg loss, 0.000000 rate, 2.347428 seconds, 1536 images, 12.214024 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 97/10000: loss=265.0 hours left=12.2
#  97: 264.982056, 857.216980 avg loss, 0.000000 rate, 2.416977 seconds, 1552 images, 12.156466 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 98/10000: loss=252.7 hours left=12.1
#  98: 252.667282, 796.762024 avg loss, 0.000000 rate, 2.490121 seconds, 1568 images, 12.101390 hours left
# Loaded: 0.000065 seconds
#
#  (next mAP calculation at 1000 iterations) 99/10000: loss=238.0 hours left=12.0
#  99: 237.982010, 740.884033 avg loss, 0.000000 rate, 2.345969 seconds, 1584 images, 12.048870 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 1000 iterations) 100/10000: loss=228.9 hours left=12.0
#  100: 228.862244, 689.681885 avg loss, 0.000000 rate, 2.380679 seconds, 1600 images, 11.992904 hours left
# Resizing, random_coef = 1.40
#
#  448 x 448
#  try to allocate additional workspace_size = 91.42 MB
#  CUDA allocate done!
# Loaded: 0.377677 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations) 101/10000: loss=151.7 hours left=11.9
#  101: 151.671906, 635.880859 avg loss, 0.000000 rate, 1.491249 seconds, 1616 images, 11.938446 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 102/10000: loss=143.1 hours left=11.9
#  102: 143.062256, 586.598999 avg loss, 0.000000 rate, 1.586648 seconds, 1632 images, 11.870452 hours left
# Loaded: 0.000058 seconds
#
#  (next mAP calculation at 1000 iterations) 103/10000: loss=140.8 hours left=11.8
#  103: 140.846619, 542.023743 avg loss, 0.000000 rate, 1.717748 seconds, 1648 images, 11.795373 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 1000 iterations) 104/10000: loss=135.2 hours left=11.7
#  104: 135.193359, 501.340698 avg loss, 0.000000 rate, 1.600747 seconds, 1664 images, 11.724645 hours left
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 1000 iterations) 105/10000: loss=127.4 hours left=11.7
#  105: 127.414108, 463.948029 avg loss, 0.000000 rate, 1.610992 seconds, 1680 images, 11.651403 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 106/10000: loss=137.8 hours left=11.6
#  106: 137.839783, 431.337219 avg loss, 0.000000 rate, 1.730198 seconds, 1696 images, 11.579171 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 107/10000: loss=124.4 hours left=11.5
#  107: 124.415779, 400.645081 avg loss, 0.000000 rate, 1.581946 seconds, 1712 images, 11.510933 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 108/10000: loss=116.8 hours left=11.4
#  108: 116.835983, 372.264160 avg loss, 0.000000 rate, 1.576359 seconds, 1728 images, 11.439298 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 1000 iterations) 109/10000: loss=127.8 hours left=11.4
#  109: 127.836540, 347.821411 avg loss, 0.000000 rate, 1.720908 seconds, 1744 images, 11.368221 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 1000 iterations) 110/10000: loss=121.8 hours left=11.3
#  110: 121.769768, 325.216248 avg loss, 0.000000 rate, 1.858006 seconds, 1760 images, 11.301822 hours left
# Resizing, random_coef = 1.40
#
#  512 x 512
#  try to allocate additional workspace_size = 117.96 MB
#  CUDA allocate done!
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 1000 iterations) 111/10000: loss=134.3 hours left=11.2
#  111: 134.256653, 306.120300 avg loss, 0.000000 rate, 1.839237 seconds, 1776 images, 11.239850 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 112/10000: loss=125.9 hours left=11.2
#  112: 125.864670, 288.094727 avg loss, 0.000000 rate, 1.844039 seconds, 1792 images, 11.177976 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations) 113/10000: loss=125.0 hours left=11.1
#  113: 125.024719, 271.787720 avg loss, 0.000000 rate, 1.896860 seconds, 1808 images, 11.116848 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations) 114/10000: loss=121.2 hours left=11.1
#  114: 121.159546, 256.724915 avg loss, 0.000000 rate, 1.897237 seconds, 1824 images, 11.057776 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 115/10000: loss=113.1 hours left=11.0
#  115: 113.061127, 242.358536 avg loss, 0.000000 rate, 1.899009 seconds, 1840 images, 10.999300 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 116/10000: loss=110.8 hours left=10.9
#  116: 110.818962, 229.204575 avg loss, 0.000000 rate, 1.942199 seconds, 1856 images, 10.941452 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 117/10000: loss=103.3 hours left=10.9
#  117: 103.303070, 216.614426 avg loss, 0.000000 rate, 1.931131 seconds, 1872 images, 10.885364 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 118/10000: loss=103.3 hours left=10.8
#  118: 103.312546, 205.284241 avg loss, 0.000000 rate, 1.859562 seconds, 1888 images, 10.829527 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 119/10000: loss=103.5 hours left=10.8
#  119: 103.501213, 195.105942 avg loss, 0.000000 rate, 1.936008 seconds, 1904 images, 10.772278 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations) 120/10000: loss=102.7 hours left=10.7
#  120: 102.659866, 185.861328 avg loss, 0.000000 rate, 1.980670 seconds, 1920 images, 10.717695 hours left
# Resizing, random_coef = 1.40
#
#  704 x 704
#  try to allocate additional workspace_size = 218.82 MB
#  CUDA allocate done!
# Loaded: 0.000066 seconds
#
#  (next mAP calculation at 1000 iterations) 121/10000: loss=168.6 hours left=10.7
#  121: 168.637177, 184.138916 avg loss, 0.000000 rate, 3.527589 seconds, 1936 images, 10.664878 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 122/10000: loss=159.2 hours left=10.7
#  122: 159.187805, 181.643799 avg loss, 0.000000 rate, 3.610995 seconds, 1952 images, 10.655035 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 123/10000: loss=152.7 hours left=10.6
#  123: 152.671768, 178.746597 avg loss, 0.000000 rate, 3.533616 seconds, 1968 images, 10.647568 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 1000 iterations) 124/10000: loss=145.2 hours left=10.6
#  124: 145.218491, 175.393784 avg loss, 0.000000 rate, 3.548928 seconds, 1984 images, 10.638043 hours left
# Loaded: 0.000063 seconds
#
#  (next mAP calculation at 1000 iterations) 125/10000: loss=136.1 hours left=10.6
#  125: 136.087616, 171.463165 avg loss, 0.000000 rate, 3.653986 seconds, 2000 images, 10.629023 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 1000 iterations) 126/10000: loss=134.5 hours left=10.6
#  126: 134.532318, 167.770081 avg loss, 0.000000 rate, 3.654536 seconds, 2016 images, 10.622966 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 127/10000: loss=120.6 hours left=10.6
#  127: 120.631012, 163.056168 avg loss, 0.000000 rate, 3.499530 seconds, 2032 images, 10.616975 hours left
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 1000 iterations) 128/10000: loss=111.8 hours left=10.6
#  128: 111.770493, 157.927597 avg loss, 0.000000 rate, 3.530309 seconds, 2048 images, 10.606781 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 129/10000: loss=103.3 hours left=10.6
#  129: 103.300072, 152.464844 avg loss, 0.000000 rate, 3.530070 seconds, 2064 images, 10.597525 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 130/10000: loss=129.1 hours left=10.6
#  130: 129.119873, 150.130341 avg loss, 0.000000 rate, 4.230709 seconds, 2080 images, 10.588344 hours left
# Resizing, random_coef = 1.40
#
#  448 x 448
#  try to allocate additional workspace_size = 91.42 MB
#  CUDA allocate done!
# Loaded: 0.000072 seconds
#
#  (next mAP calculation at 1000 iterations) 131/10000: loss=45.8 hours left=10.6
#  131: 45.795967, 139.696899 avg loss, 0.000000 rate, 1.578497 seconds, 2096 images, 10.598454 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 1000 iterations) 132/10000: loss=52.3 hours left=10.5
#  132: 52.325722, 130.959778 avg loss, 0.000000 rate, 1.827661 seconds, 2112 images, 10.535744 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 133/10000: loss=44.8 hours left=10.5
#  133: 44.816528, 122.345451 avg loss, 0.000000 rate, 1.823078 seconds, 2128 images, 10.480487 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 1000 iterations) 134/10000: loss=35.2 hours left=10.4
#  134: 35.226608, 113.633568 avg loss, 0.000000 rate, 1.667222 seconds, 2144 images, 10.425651 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 135/10000: loss=33.1 hours left=10.4
#  135: 33.056171, 105.575829 avg loss, 0.000000 rate, 1.582145 seconds, 2160 images, 10.367087 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 136/10000: loss=32.2 hours left=10.3
#  136: 32.245144, 98.242760 avg loss, 0.000000 rate, 1.547607 seconds, 2176 images, 10.306773 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 1000 iterations) 137/10000: loss=31.8 hours left=10.2
#  137: 31.832443, 91.601730 avg loss, 0.000000 rate, 1.540116 seconds, 2192 images, 10.246111 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 138/10000: loss=29.8 hours left=10.2
#  138: 29.806198, 85.422180 avg loss, 0.000000 rate, 1.620812 seconds, 2208 images, 10.185847 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 139/10000: loss=25.3 hours left=10.1
#  139: 25.287996, 79.408760 avg loss, 0.000000 rate, 1.555233 seconds, 2224 images, 10.128391 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 140/10000: loss=22.9 hours left=10.1
#  140: 22.864750, 73.754356 avg loss, 0.000000 rate, 1.684340 seconds, 2240 images, 10.069709 hours left
# Resizing, random_coef = 1.40
#
#  448 x 448
#  try to allocate additional workspace_size = 91.42 MB
#  CUDA allocate done!
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations) 141/10000: loss=25.3 hours left=10.0
#  141: 25.346893, 68.913612 avg loss, 0.000000 rate, 1.640073 seconds, 2256 images, 10.015146 hours left
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 1000 iterations) 142/10000: loss=34.4 hours left=10.0
#  142: 34.379139, 65.460167 avg loss, 0.000000 rate, 1.678665 seconds, 2272 images, 9.959912 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 143/10000: loss=20.5 hours left=9.9
#  143: 20.505051, 60.964657 avg loss, 0.000000 rate, 1.557610 seconds, 2288 images, 9.906282 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations) 144/10000: loss=23.0 hours left=9.8
#  144: 22.954014, 57.163593 avg loss, 0.000000 rate, 1.571635 seconds, 2304 images, 9.849869 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 145/10000: loss=26.1 hours left=9.8
#  145: 26.070568, 54.054291 avg loss, 0.000000 rate, 1.600485 seconds, 2320 images, 9.794400 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 146/10000: loss=18.3 hours left=9.7
#  146: 18.286686, 50.477531 avg loss, 0.000000 rate, 1.541157 seconds, 2336 images, 9.740270 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 147/10000: loss=31.6 hours left=9.7
#  147: 31.577084, 48.587486 avg loss, 0.000000 rate, 1.704691 seconds, 2352 images, 9.685055 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 148/10000: loss=20.7 hours left=9.6
#  148: 20.749746, 45.803711 avg loss, 0.000000 rate, 1.780551 seconds, 2368 images, 9.634862 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 149/10000: loss=24.8 hours left=9.6
#  149: 24.786343, 43.701973 avg loss, 0.000000 rate, 1.716557 seconds, 2384 images, 9.587243 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 150/10000: loss=16.0 hours left=9.5
#  150: 16.041889, 40.935966 avg loss, 0.000001 rate, 1.564560 seconds, 2400 images, 9.538344 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 79.48 MB
#  CUDA allocate done!
# Loaded: 0.063249 seconds
#
#  (next mAP calculation at 1000 iterations) 151/10000: loss=17.9 hours left=9.5
#  151: 17.934706, 38.635841 avg loss, 0.000001 rate, 1.400037 seconds, 2416 images, 9.485771 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 152/10000: loss=20.0 hours left=9.4
#  152: 19.993624, 36.771618 avg loss, 0.000001 rate, 1.478404 seconds, 2432 images, 9.430946 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 153/10000: loss=23.2 hours left=9.4
#  153: 23.184603, 35.412918 avg loss, 0.000001 rate, 1.483294 seconds, 2448 images, 9.377081 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 1000 iterations) 154/10000: loss=14.6 hours left=9.3
#  154: 14.567031, 33.328331 avg loss, 0.000001 rate, 1.458107 seconds, 2464 images, 9.323884 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations) 155/10000: loss=12.7 hours left=9.3
#  155: 12.735474, 31.269045 avg loss, 0.000001 rate, 1.452912 seconds, 2480 images, 9.270526 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 156/10000: loss=15.7 hours left=9.2
#  156: 15.708640, 29.713005 avg loss, 0.000001 rate, 1.578569 seconds, 2496 images, 9.217555 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 1000 iterations) 157/10000: loss=14.7 hours left=9.2
#  157: 14.653917, 28.207096 avg loss, 0.000001 rate, 1.514203 seconds, 2512 images, 9.168547 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations) 158/10000: loss=16.1 hours left=9.1
#  158: 16.142488, 27.000635 avg loss, 0.000001 rate, 1.433762 seconds, 2528 images, 9.118264 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 159/10000: loss=19.1 hours left=9.1
#  159: 19.148449, 26.215416 avg loss, 0.000001 rate, 1.489231 seconds, 2544 images, 9.066280 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 1000 iterations) 160/10000: loss=19.4 hours left=9.0
#  160: 19.406475, 25.534521 avg loss, 0.000001 rate, 1.513521 seconds, 2560 images, 9.016329 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 79.48 MB
#  CUDA allocate done!
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 161/10000: loss=14.0 hours left=9.0
#  161: 13.981944, 24.379263 avg loss, 0.000001 rate, 1.354147 seconds, 2576 images, 8.967536 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 162/10000: loss=10.8 hours left=8.9
#  162: 10.756310, 23.016968 avg loss, 0.000001 rate, 1.472445 seconds, 2592 images, 8.914872 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 163/10000: loss=22.1 hours left=8.9
#  163: 22.138882, 22.929159 avg loss, 0.000001 rate, 1.500301 seconds, 2608 images, 8.865964 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 164/10000: loss=12.1 hours left=8.8
#  164: 12.064538, 21.842697 avg loss, 0.000001 rate, 1.534250 seconds, 2624 images, 8.818302 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 165/10000: loss=11.9 hours left=8.8
#  165: 11.888600, 20.847288 avg loss, 0.000001 rate, 1.520789 seconds, 2640 images, 8.772039 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 166/10000: loss=19.3 hours left=8.7
#  166: 19.279463, 20.690506 avg loss, 0.000001 rate, 1.487201 seconds, 2656 images, 8.725868 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 167/10000: loss=9.1 hours left=8.7
#  167: 9.079392, 19.529394 avg loss, 0.000001 rate, 1.420268 seconds, 2672 images, 8.679236 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 168/10000: loss=11.2 hours left=8.6
#  168: 11.238013, 18.700256 avg loss, 0.000001 rate, 1.464436 seconds, 2688 images, 8.631238 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 169/10000: loss=39.7 hours left=8.6
#  169: 39.712887, 20.801519 avg loss, 0.000001 rate, 1.580843 seconds, 2704 images, 8.584923 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations) 170/10000: loss=14.6 hours left=8.5
#  170: 14.632697, 20.184637 avg loss, 0.000001 rate, 1.531090 seconds, 2720 images, 8.542245 hours left
# Resizing, random_coef = 1.40
#
#  704 x 704
#  try to allocate additional workspace_size = 218.82 MB
#  CUDA allocate done!
# Loaded: 0.000058 seconds
#
#  (next mAP calculation at 1000 iterations) 171/10000: loss=20.4 hours left=8.5
#  171: 20.420708, 20.208244 avg loss, 0.000001 rate, 3.589632 seconds, 2736 images, 8.498631 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 172/10000: loss=16.2 hours left=8.5
#  172: 16.173138, 19.804733 avg loss, 0.000001 rate, 3.499313 seconds, 2752 images, 8.511654 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 173/10000: loss=16.3 hours left=8.5
#  173: 16.263390, 19.450600 avg loss, 0.000001 rate, 3.504951 seconds, 2768 images, 8.522070 hours left
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 1000 iterations) 174/10000: loss=16.8 hours left=8.5
#  174: 16.824598, 19.188000 avg loss, 0.000001 rate, 3.628160 seconds, 2784 images, 8.532527 hours left
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 1000 iterations) 175/10000: loss=15.3 hours left=8.5
#  175: 15.283566, 18.797556 avg loss, 0.000001 rate, 3.618191 seconds, 2800 images, 8.546232 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations) 176/10000: loss=21.9 hours left=8.6
#  176: 21.856623, 19.103462 avg loss, 0.000001 rate, 3.744828 seconds, 2816 images, 8.559518 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 177/10000: loss=13.4 hours left=8.6
#  177: 13.350674, 18.528183 avg loss, 0.000001 rate, 3.507730 seconds, 2832 images, 8.576117 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 178/10000: loss=12.6 hours left=8.6
#  178: 12.588469, 17.934212 avg loss, 0.000001 rate, 3.580816 seconds, 2848 images, 8.586070 hours left
# Loaded: 0.000065 seconds
#
#  (next mAP calculation at 1000 iterations) 179/10000: loss=16.0 hours left=8.6
#  179: 16.023586, 17.743149 avg loss, 0.000001 rate, 3.586533 seconds, 2864 images, 8.597908 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 180/10000: loss=14.8 hours left=8.6
#  180: 14.803363, 17.449171 avg loss, 0.000001 rate, 3.544620 seconds, 2880 images, 8.609773 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 79.48 MB
#  CUDA allocate done!
# Loaded: 0.000058 seconds
#
#  (next mAP calculation at 1000 iterations) 181/10000: loss=7.3 hours left=8.6
#  181: 7.346447, 16.438898 avg loss, 0.000001 rate, 1.501879 seconds, 2896 images, 8.620367 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 1000 iterations) 182/10000: loss=9.2 hours left=8.6
#  182: 9.184607, 15.713469 avg loss, 0.000001 rate, 2.001549 seconds, 2912 images, 8.575129 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations) 183/10000: loss=7.6 hours left=8.5
#  183: 7.596631, 14.901785 avg loss, 0.000001 rate, 1.949145 seconds, 2928 images, 8.543966 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations) 184/10000: loss=11.7 hours left=8.5
#  184: 11.698839, 14.581491 avg loss, 0.000001 rate, 1.723572 seconds, 2944 images, 8.511681 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 185/10000: loss=12.0 hours left=8.5
#  185: 12.049033, 14.328245 avg loss, 0.000001 rate, 1.495862 seconds, 2960 images, 8.473562 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 186/10000: loss=9.7 hours left=8.4
#  186: 9.722489, 13.867670 avg loss, 0.000001 rate, 1.495142 seconds, 2976 images, 8.429611 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 187/10000: loss=23.8 hours left=8.4
#  187: 23.800673, 14.860970 avg loss, 0.000001 rate, 1.582877 seconds, 2992 images, 8.386075 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 1000 iterations) 188/10000: loss=18.2 hours left=8.3
#  188: 18.210794, 15.195953 avg loss, 0.000001 rate, 1.535674 seconds, 3008 images, 8.345363 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations) 189/10000: loss=6.8 hours left=8.3
#  189: 6.832026, 14.359561 avg loss, 0.000001 rate, 1.444567 seconds, 3024 images, 8.303766 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 190/10000: loss=4.5 hours left=8.3
#  190: 4.524165, 13.376021 avg loss, 0.000001 rate, 1.484180 seconds, 3040 images, 8.260098 hours left
# Resizing, random_coef = 1.40
#
#  480 x 480
#  try to allocate additional workspace_size = 104.25 MB
#  CUDA allocate done!
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 191/10000: loss=7.9 hours left=8.2
#  191: 7.879231, 12.826343 avg loss, 0.000001 rate, 1.848015 seconds, 3056 images, 8.217943 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 1000 iterations) 192/10000: loss=7.6 hours left=8.2
#  192: 7.619162, 12.305624 avg loss, 0.000001 rate, 1.779061 seconds, 3072 images, 8.186119 hours left
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 1000 iterations) 193/10000: loss=6.1 hours left=8.2
#  193: 6.078579, 11.682920 avg loss, 0.000001 rate, 1.752769 seconds, 3088 images, 8.152728 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 194/10000: loss=11.9 hours left=8.1
#  194: 11.899923, 11.704620 avg loss, 0.000001 rate, 1.790202 seconds, 3104 images, 8.118951 hours left
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 1000 iterations) 195/10000: loss=42.4 hours left=8.1
#  195: 42.402874, 14.774446 avg loss, 0.000001 rate, 2.054598 seconds, 3120 images, 8.086526 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 196/10000: loss=11.0 hours left=8.1
#  196: 10.997232, 14.396725 avg loss, 0.000001 rate, 1.807615 seconds, 3136 images, 8.061622 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 197/10000: loss=8.6 hours left=8.0
#  197: 8.578999, 13.814952 avg loss, 0.000002 rate, 1.893633 seconds, 3152 images, 8.030235 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 198/10000: loss=11.0 hours left=8.0
#  198: 11.024258, 13.535883 avg loss, 0.000002 rate, 1.952863 seconds, 3168 images, 8.001499 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations) 199/10000: loss=10.2 hours left=8.0
#  199: 10.230927, 13.205387 avg loss, 0.000002 rate, 1.738188 seconds, 3184 images, 7.974658 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 200/10000: loss=9.1 hours left=7.9
#  200: 9.099339, 12.794783 avg loss, 0.000002 rate, 1.760979 seconds, 3200 images, 7.942235 hours left
# Resizing, random_coef = 1.40
#
#  704 x 704
#  try to allocate additional workspace_size = 218.82 MB
#  CUDA allocate done!
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 1000 iterations) 201/10000: loss=15.8 hours left=7.9
#  201: 15.778435, 13.093148 avg loss, 0.000002 rate, 3.663774 seconds, 3216 images, 7.910752 hours left
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 1000 iterations) 202/10000: loss=11.0 hours left=7.9
#  202: 10.973185, 12.881152 avg loss, 0.000002 rate, 3.902445 seconds, 3232 images, 7.931372 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 203/10000: loss=10.1 hours left=8.0
#  203: 10.128134, 12.605850 avg loss, 0.000002 rate, 3.640208 seconds, 3248 images, 7.958272 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations) 204/10000: loss=7.8 hours left=8.0
#  204: 7.750093, 12.120275 avg loss, 0.000002 rate, 3.476555 seconds, 3264 images, 7.977755 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 205/10000: loss=9.0 hours left=8.0
#  205: 9.048997, 11.813147 avg loss, 0.000002 rate, 3.716622 seconds, 3280 images, 7.992581 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 206/10000: loss=9.5 hours left=8.0
#  206: 9.525805, 11.584413 avg loss, 0.000002 rate, 3.554378 seconds, 3296 images, 8.013780 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 207/10000: loss=8.1 hours left=8.0
#  207: 8.077019, 11.233673 avg loss, 0.000002 rate, 3.514591 seconds, 3312 images, 8.030348 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations) 208/10000: loss=10.7 hours left=8.0
#  208: 10.716066, 11.181912 avg loss, 0.000002 rate, 3.655031 seconds, 3328 images, 8.045652 hours left
# Loaded: 0.000084 seconds
#
#  (next mAP calculation at 1000 iterations) 209/10000: loss=8.2 hours left=8.1
#  209: 8.238981, 10.887619 avg loss, 0.000002 rate, 3.742517 seconds, 3344 images, 8.064615 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 210/10000: loss=8.0 hours left=8.1
#  210: 7.973532, 10.596210 avg loss, 0.000002 rate, 3.543439 seconds, 3360 images, 8.085757 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 79.48 MB
#  CUDA allocate done!
# Loaded: 0.068877 seconds
#
#  (next mAP calculation at 1000 iterations) 211/10000: loss=7.9 hours left=8.1
#  211: 7.932182, 10.329807 avg loss, 0.000002 rate, 1.419629 seconds, 3376 images, 8.101263 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations) 212/10000: loss=11.5 hours left=8.1
# ...
# Resizing, random_coef = 1.40
#
#  480 x 480
#  try to allocate additional workspace_size = 104.25 MB
#  CUDA allocate done!
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 1000 iterations) 931/10000: loss=2.8 hours left=5.4
#  931: 2.837679, 2.957497 avg loss, 0.000751 rate, 1.709708 seconds, 14896 images, 5.413974 hours left
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 1000 iterations) 932/10000: loss=1.8 hours left=5.4
#  932: 1.766229, 2.838370 avg loss, 0.000755 rate, 1.862915 seconds, 14912 images, 5.402906 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 933/10000: loss=2.7 hours left=5.4
#  933: 2.660711, 2.820604 avg loss, 0.000758 rate, 1.782337 seconds, 14928 images, 5.395804 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 1000 iterations) 934/10000: loss=3.2 hours left=5.4
#  934: 3.184271, 2.856971 avg loss, 0.000761 rate, 1.755149 seconds, 14944 images, 5.386737 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 1000 iterations) 935/10000: loss=3.1 hours left=5.4
#  935: 3.114273, 2.882701 avg loss, 0.000764 rate, 1.829945 seconds, 14960 images, 5.377072 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 936/10000: loss=1.6 hours left=5.4
#  936: 1.611888, 2.755620 avg loss, 0.000768 rate, 1.883411 seconds, 14976 images, 5.369381 hours left
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 1000 iterations) 937/10000: loss=2.5 hours left=5.4
#  937: 2.485711, 2.728629 avg loss, 0.000771 rate, 1.740429 seconds, 14992 images, 5.363109 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 938/10000: loss=2.0 hours left=5.4
#  938: 1.994701, 2.655236 avg loss, 0.000774 rate, 1.772564 seconds, 15008 images, 5.353295 hours left
# Loaded: 0.000181 seconds
#
#  (next mAP calculation at 1000 iterations) 939/10000: loss=2.8 hours left=5.3
#  939: 2.846401, 2.674352 avg loss, 0.000777 rate, 1.797820 seconds, 15024 images, 5.344383 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 1000 iterations) 940/10000: loss=2.5 hours left=5.3
#  940: 2.479708, 2.654888 avg loss, 0.000781 rate, 1.766527 seconds, 15040 images, 5.336194 hours left
# Resizing, random_coef = 1.40
#
#  480 x 480
#  try to allocate additional workspace_size = 104.25 MB
#  CUDA allocate done!
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 1000 iterations) 941/10000: loss=2.0 hours left=5.3
#  941: 2.018734, 2.591272 avg loss, 0.000784 rate, 1.641389 seconds, 15056 images, 5.327292 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 1000 iterations) 942/10000: loss=5.9 hours left=5.3
#  942: 5.859943, 2.918139 avg loss, 0.000787 rate, 2.058789 seconds, 15072 images, 5.315324 hours left
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 1000 iterations) 943/10000: loss=2.0 hours left=5.3
#  943: 2.046605, 2.830986 avg loss, 0.000791 rate, 1.860645 seconds, 15088 images, 5.313974 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 944/10000: loss=1.5 hours left=5.3
#  944: 1.481726, 2.696060 avg loss, 0.000794 rate, 1.726597 seconds, 15104 images, 5.307646 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 945/10000: loss=2.1 hours left=5.3
#  945: 2.128273, 2.639282 avg loss, 0.000797 rate, 1.737619 seconds, 15120 images, 5.298005 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 946/10000: loss=2.8 hours left=5.3
#  946: 2.785438, 2.653897 avg loss, 0.000801 rate, 1.779522 seconds, 15136 images, 5.288732 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations) 947/10000: loss=3.6 hours left=5.3
#  947: 3.620891, 2.750597 avg loss, 0.000804 rate, 1.823543 seconds, 15152 images, 5.280602 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations) 948/10000: loss=2.8 hours left=5.3
#  948: 2.756767, 2.751214 avg loss, 0.000808 rate, 1.810047 seconds, 15168 images, 5.273654 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 949/10000: loss=1.5 hours left=5.3
#  949: 1.524598, 2.628552 avg loss, 0.000811 rate, 1.796123 seconds, 15184 images, 5.266431 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 950/10000: loss=2.6 hours left=5.3
#  950: 2.626258, 2.628323 avg loss, 0.000815 rate, 1.830329 seconds, 15200 images, 5.258926 hours left
# Resizing, random_coef = 1.40
#
#  640 x 640
#  try to allocate additional workspace_size = 181.67 MB
#  CUDA allocate done!
# Loaded: 0.000064 seconds
#
#  (next mAP calculation at 1000 iterations) 951/10000: loss=1.9 hours left=5.3
#  951: 1.863426, 2.551833 avg loss, 0.000818 rate, 2.843323 seconds, 15216 images, 5.252351 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 952/10000: loss=2.2 hours left=5.3
#  952: 2.156335, 2.512283 avg loss, 0.000821 rate, 2.982727 seconds, 15232 images, 5.271299 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 953/10000: loss=3.2 hours left=5.3
#  953: 3.163676, 2.577422 avg loss, 0.000825 rate, 3.100426 seconds, 15248 images, 5.293553 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 1000 iterations) 954/10000: loss=2.0 hours left=5.3
#  954: 1.974504, 2.517131 avg loss, 0.000828 rate, 3.145505 seconds, 15264 images, 5.318535 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 955/10000: loss=2.2 hours left=5.3
#  955: 2.246621, 2.490080 avg loss, 0.000832 rate, 3.018871 seconds, 15280 images, 5.344391 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 956/10000: loss=3.1 hours left=5.4
#  956: 3.120754, 2.553147 avg loss, 0.000835 rate, 3.075398 seconds, 15296 images, 5.366797 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 957/10000: loss=2.6 hours left=5.4
#  957: 2.594121, 2.557245 avg loss, 0.000839 rate, 3.057186 seconds, 15312 images, 5.390392 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 958/10000: loss=2.3 hours left=5.4
#  958: 2.347478, 2.536268 avg loss, 0.000842 rate, 3.250069 seconds, 15328 images, 5.413284 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 959/10000: loss=1.8 hours left=5.4
#  959: 1.801683, 2.462810 avg loss, 0.000846 rate, 2.966355 seconds, 15344 images, 5.440784 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 960/10000: loss=1.5 hours left=5.5
#  960: 1.512457, 2.367774 avg loss, 0.000849 rate, 2.936209 seconds, 15360 images, 5.460875 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 164.41 MB
#  CUDA allocate done!
# Loaded: 0.000069 seconds
#
#  (next mAP calculation at 1000 iterations) 961/10000: loss=1.6 hours left=5.5
#  961: 1.584338, 2.289431 avg loss, 0.000853 rate, 2.690068 seconds, 15376 images, 5.479999 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 962/10000: loss=1.7 hours left=5.5
#  962: 1.670560, 2.227544 avg loss, 0.000856 rate, 2.985345 seconds, 15392 images, 5.492744 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 963/10000: loss=3.7 hours left=5.5
#  963: 3.685565, 2.373346 avg loss, 0.000860 rate, 2.883503 seconds, 15408 images, 5.512767 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 964/10000: loss=2.5 hours left=5.5
#  964: 2.532778, 2.389289 avg loss, 0.000864 rate, 2.806191 seconds, 15424 images, 5.530025 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 965/10000: loss=1.7 hours left=5.5
#  965: 1.698507, 2.320211 avg loss, 0.000867 rate, 2.741590 seconds, 15440 images, 5.545161 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 1000 iterations) 966/10000: loss=2.0 hours left=5.6
#  966: 2.018621, 2.290052 avg loss, 0.000871 rate, 2.903045 seconds, 15456 images, 5.558517 hours left
# Loaded: 0.000063 seconds
#
#  (next mAP calculation at 1000 iterations) 967/10000: loss=1.3 hours left=5.6
#  967: 1.337428, 2.194789 avg loss, 0.000874 rate, 2.767767 seconds, 15472 images, 5.575784 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations) 968/10000: loss=1.9 hours left=5.6
#  968: 1.881258, 2.163436 avg loss, 0.000878 rate, 2.758821 seconds, 15488 images, 5.589476 hours left
# Loaded: 0.000066 seconds
#
#  (next mAP calculation at 1000 iterations) 969/10000: loss=3.5 hours left=5.6
#  969: 3.547925, 2.301885 avg loss, 0.000882 rate, 2.852069 seconds, 15504 images, 5.602799 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 1000 iterations) 970/10000: loss=2.5 hours left=5.6
#  970: 2.476366, 2.319333 avg loss, 0.000885 rate, 2.919764 seconds, 15520 images, 5.618320 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 79.48 MB
#  CUDA allocate done!
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 971/10000: loss=2.7 hours left=5.6
#  971: 2.653430, 2.352743 avg loss, 0.000889 rate, 1.579485 seconds, 15536 images, 5.635376 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 1000 iterations) 972/10000: loss=1.6 hours left=5.6
#  972: 1.589319, 2.276401 avg loss, 0.000893 rate, 1.392794 seconds, 15552 images, 5.618639 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 973/10000: loss=2.5 hours left=5.6
#  973: 2.534689, 2.302229 avg loss, 0.000896 rate, 1.452212 seconds, 15568 images, 5.597382 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 974/10000: loss=2.4 hours left=5.6
#  974: 2.423701, 2.314377 avg loss, 0.000900 rate, 1.449507 seconds, 15584 images, 5.577823 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 975/10000: loss=2.3 hours left=5.6
#  975: 2.262994, 2.309238 avg loss, 0.000904 rate, 1.471738 seconds, 15600 images, 5.558389 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 976/10000: loss=2.2 hours left=5.5
#  976: 2.211142, 2.299429 avg loss, 0.000907 rate, 1.427022 seconds, 15616 images, 5.539702 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 977/10000: loss=2.1 hours left=5.5
#  977: 2.079462, 2.277432 avg loss, 0.000911 rate, 1.458609 seconds, 15632 images, 5.520077 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 1000 iterations) 978/10000: loss=2.1 hours left=5.5
#  978: 2.142188, 2.263907 avg loss, 0.000915 rate, 1.505936 seconds, 15648 images, 5.501436 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations) 979/10000: loss=2.2 hours left=5.5
#  979: 2.245192, 2.262036 avg loss, 0.000919 rate, 1.576108 seconds, 15664 images, 5.484164 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 980/10000: loss=3.4 hours left=5.5
#  980: 3.429658, 2.378798 avg loss, 0.000922 rate, 1.508055 seconds, 15680 images, 5.468818 hours left
# Resizing, random_coef = 1.40
#
#  512 x 512
#  try to allocate additional workspace_size = 117.96 MB
#  CUDA allocate done!
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 1000 iterations) 981/10000: loss=2.6 hours left=5.5
#  981: 2.646587, 2.405577 avg loss, 0.000926 rate, 1.807207 seconds, 15696 images, 5.451917 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations) 982/10000: loss=2.0 hours left=5.4
#  982: 1.981410, 2.363160 avg loss, 0.000930 rate, 1.841468 seconds, 15712 images, 5.442675 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 983/10000: loss=1.4 hours left=5.4
#  983: 1.392607, 2.266105 avg loss, 0.000934 rate, 1.890591 seconds, 15728 images, 5.434378 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations) 984/10000: loss=3.1 hours left=5.4
#  984: 3.125915, 2.352086 avg loss, 0.000938 rate, 1.920575 seconds, 15744 images, 5.427390 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations) 985/10000: loss=2.5 hours left=5.4
#  985: 2.482014, 2.365079 avg loss, 0.000941 rate, 2.187637 seconds, 15760 images, 5.421217 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 1000 iterations) 986/10000: loss=1.8 hours left=5.4
#  986: 1.830463, 2.311617 avg loss, 0.000945 rate, 2.007954 seconds, 15776 images, 5.421788 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 987/10000: loss=2.5 hours left=5.4
#  987: 2.473649, 2.327820 avg loss, 0.000949 rate, 1.916099 seconds, 15792 images, 5.417849 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations) 988/10000: loss=2.3 hours left=5.4
#  988: 2.251420, 2.320180 avg loss, 0.000953 rate, 1.890264 seconds, 15808 images, 5.411643 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 989/10000: loss=1.6 hours left=5.4
#  989: 1.552117, 2.243374 avg loss, 0.000957 rate, 1.851001 seconds, 15824 images, 5.404848 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 990/10000: loss=3.5 hours left=5.4
#  990: 3.474739, 2.366510 avg loss, 0.000961 rate, 1.935987 seconds, 15840 images, 5.397132 hours left
# Resizing, random_coef = 1.40
#
#  704 x 704
#  try to allocate additional workspace_size = 218.82 MB
#  CUDA allocate done!
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 1000 iterations) 991/10000: loss=4.7 hours left=5.4
#  991: 4.689314, 2.598791 avg loss, 0.000964 rate, 3.989734 seconds, 15856 images, 5.391616 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations) 992/10000: loss=2.3 hours left=5.4
#  992: 2.322601, 2.571172 avg loss, 0.000968 rate, 3.561183 seconds, 15872 images, 5.437545 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations) 993/10000: loss=2.0 hours left=5.5
#  993: 1.988707, 2.512925 avg loss, 0.000972 rate, 3.544381 seconds, 15888 images, 5.472280 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations) 994/10000: loss=4.1 hours left=5.5
#  994: 4.053307, 2.666963 avg loss, 0.000976 rate, 3.895988 seconds, 15904 images, 5.506237 hours left
# Loaded: 0.000069 seconds
#
#  (next mAP calculation at 1000 iterations) 995/10000: loss=4.1 hours left=5.5
#  995: 4.054476, 2.805715 avg loss, 0.000980 rate, 3.639359 seconds, 15920 images, 5.548641 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations) 996/10000: loss=4.9 hours left=5.6
#  996: 4.922892, 3.017432 avg loss, 0.000984 rate, 3.705295 seconds, 15936 images, 5.584191 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 1000 iterations) 997/10000: loss=1.4 hours left=5.6
#  997: 1.352362, 2.850925 avg loss, 0.000988 rate, 3.521189 seconds, 15952 images, 5.621024 hours left
# Loaded: 0.000064 seconds
#
#  (next mAP calculation at 1000 iterations) 998/10000: loss=2.7 hours left=5.7
#  998: 2.680253, 2.833858 avg loss, 0.000992 rate, 3.778127 seconds, 15968 images, 5.652875 hours left
# Loaded: 0.000067 seconds
#
#  (next mAP calculation at 1000 iterations) 999/10000: loss=2.2 hours left=5.7
#  999: 2.237169, 2.774189 avg loss, 0.000996 rate, 3.514718 seconds, 15984 images, 5.690823 hours left
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 1000 iterations) 1000/10000: loss=3.5 hours left=5.7
#  1000: 3.535710, 2.850341 avg loss, 0.001000 rate, 3.626623 seconds, 16000 images, 5.721794 hours left
# Resizing to initial size: 512 x 512  try to allocate additional workspace_size = 117.96 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
#
#  cuDNN status Error in: file: ./src/convolutional_kernels.cu function: forward_convolutional_layer_gpu() line: 541
#
#  cuDNN Error: CUDNN_STATUS_BAD_PARAM
# /bin/bash: line 1:  7844 Segmentation fault      (core dumped) ./darknet/darknet detector train FacialMaskDetector\/yolov3\/config\/yolov3-mask_nomask-setup.data FacialMaskDetector\/yolov3\/config\/yolov3-mask_nomask-train.cfg FacialMaskDetector\/yolov3\/weights\/darknet53.conv.74 -dont_show -map 2> train_log.txt

# %% [markdown]
# Our results:
#
# - Last accuracy mAP@0.5 = 87.71 %, best = 88.44 %
#  10000: 0.678672, 0.730213 avg loss, 0.000001 rate, 3.044799 seconds, 160000 images, 0.056984 hours left
#
# - detections_count = 3096, unique_truth_count = 1517
# - class_id = 0, name = Mask, ap = 92.32%   	 (TP = 462, FP = 42)
# - class_id = 1, name = No-Mask, ap = 82.30%   	 (TP = 747, FP = 93)
#
# And the training time was about 8 to 10 hours.
#
#
#
# _____
#
# with the first 1000 we only got to 28 of mAP :c

# %% [markdown]
# ### <font color="pink">13. Displaying code</font>
#
# This code will display in the same canvas both images, the original one and the yolo predictions marked on it.

# %%
def display_output(imagePath):
    src = cv2.imread(imagePath,1)
    output = cv2.imread("predictions.jpg")

    plt.figure(figsize=[20,8])
    plt.subplot(121)
    plt.imshow(src[:,:,::-1])
    plt.title("Original Image")
    plt.subplot(122)
    plt.imshow(output[:,:,::-1])
    plt.title("Predictions")

    file_name = imagePath.split('/')
    file_name_parts = file_name[2].split('.')
    name_only = file_name_parts[0]
    now = datetime.now() # current date and time
    build = now.strftime("%m-%d-%Y_%H_%M_%S")
    file_save_path = os.path.join(file_name[0], 'result', 'yolov3')
    save_name = os.path.join(file_save_path, name_only + '-yolov3--' + build +'.png')
    print(f"Saved at: {save_name}")
    plt.savefig(save_name)

    plt.show()

# %% [markdown]
# ### <font color="pink">14. Making Inferences </font>
#
# This code will display in the same canvas both images, the original one and the yolo predictions marked on it.
#
# Finally are the inferences of images and pre-recorded video.
#
# The pre-recorded video could be downloaded over the root folder, in this case, our YOLO folder (created on Google Drive).

# %% [markdown]
# Here are the files paths:

# %%
# %cd /content/drive/My\ Drive/YOLO
yolo_test_path = os.path.join('FacialMaskDetector', 'test')
test_files = [os.path.join(yolo_test_path, v) for v in os.listdir(yolo_test_path)]
# Out:
# /content/drive/My Drive/YOLO

# %% [markdown]
# #### <font color="pink">14.1 Scenario 1</font>
#
# Testing only with one man and with facemask....aaand it doesn't work :c

# %%
# Uncomment the line belowif you prebuilt darknet and want to change the permissions of the file
#!chmod 777 /content/drive/My\ Drive/YOLO/darknet/darknet
# %cd /content/drive/My\ Drive/YOLO
# !./darknet/darknet detector test $yolo_setup $yolo_test $yolo_best_weights FacialMaskDetector/test/test-image1.jpg -thresh .6 2> /dev/null
display_output(test_files[0])
# Out:
# /content/drive/My Drive/YOLO
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-f578d359473c> in <cell line: 5>()
#       3 get_ipython().run_line_magic('cd', '/content/drive/My\\ Drive/YOLO')
#       4 get_ipython().system('./darknet/darknet detector test $yolo_setup $yolo_test $yolo_best_weights FacialMaskDetector/test/test-image1.jpg -thresh .6 2> /dev/null')
# ----> 5 display_output(test_files[0])
#
# <ipython-input-66-39cd4ab51312> in display_output(imagePath)
#       8     plt.title("Original Image")
#       9     plt.subplot(122)
# ---> 10     plt.imshow(output[:,:,::-1])
#      11     plt.title("Predictions")
#      12
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# #### <font color="pink">14.2 Scenario 2</font>
#
# Testing with different angles of people wearing mask and other not wearing.

# %%
# !./darknet/darknet detector test $yolo_setup $yolo_test $yolo_best_weights FacialMaskDetector/test/test-image2.jpg -thresh .6 2> /dev/null
display_output(test_files[1])
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#
#  seen 64, trained: 122 K-images (1 Kilo-batches_64)
# FacialMaskDetector/test/test-image2.jpg: Predicted in 33.228000 milli-seconds.
# Mask: 100%
# Mask: 99%
# Mask: 99%
# No-Mask: 100%
# Mask: 99%
# Saved at: FacialMaskDetector/result/yolov3/test-image2-yolov3--06-12-2020_07_27_42.png

# %% [markdown]
# #### <font color="pink">14.3 Scenario 3</font>
#
# Testing with a crowd with and without facemask and different scales and variations

# %%
# !./darknet/darknet detector test $yolo_setup $yolo_test $yolo_best_weights FacialMaskDetector/test/test-image3.jpg -thresh .6 2> /dev/null
display_output(test_files[2])
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#
#  seen 64, trained: 122 K-images (1 Kilo-batches_64)
# FacialMaskDetector/test/test-image3.jpg: Predicted in 33.287000 milli-seconds.
# Mask: 99%
# Mask: 99%
# Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
# Mask: 100%
# Saved at: FacialMaskDetector/result/yolov3/test-image3-yolov3--06-12-2020_07_27_56.png

# %% [markdown]
# #### <font color="pink">14.4 Scenario 4</font>
#
# Testing with several people walking trough the plaza.

# %%
# !./darknet/darknet detector test $yolo_setup $yolo_test $yolo_best_weights FacialMaskDetector/test/test-image4.jpg -thresh .5 2> /dev/null
display_output(test_files[3])
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#
#  seen 64, trained: 122 K-images (1 Kilo-batches_64)
# FacialMaskDetector/test/test-image4.jpg: Predicted in 33.091000 milli-seconds.
# No-Mask: 99%
# No-Mask: 77%
# Mask: 100%
# Mask: 100%
# No-Mask: 97%
# Mask: 100%
# No-Mask: 58%
# Mask: 100%
# Saved at: FacialMaskDetector/result/yolov3/test-image4-yolov3--06-12-2020_07_28_59.png

# %% [markdown]
# #### <font color="pink">14.5 Scenario 5</font>
#
# Testing over a video of people wearing or not wearing mask, good lighting conditions.

# %%
# !./darknet/darknet detector demo $yolo_setup $yolo_test $yolo_best_weights FacialMaskDetector/test/test-video1.mp4 -thresh .6 2 -out_filename out-vid1.avi -dont_show
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
#
# FPS:28.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
#
# FPS:28.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 98%
#
# FPS:28.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 91%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:28.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 97%
#
# FPS:28.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:28.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:28.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.5 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.2 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.2 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.3 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.5 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.2 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.3 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.6 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.3 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.2 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.4 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.3 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.2 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.0 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.7 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.7 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.0 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.3 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:26.3 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:26.6 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:26.9 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.9 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.5 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.4 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.4 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.2 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.2 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.2 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.7 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.4 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.7 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.3 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.6 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.4 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.7 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.4 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.7 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.4 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.7 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.5 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.6 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.7 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.0 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.7 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.0 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.0 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 86%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.4 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 98%
#
# FPS:26.0 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 98%
#
# FPS:26.5 	 AVG_FPS:28.3
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:26.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 69%
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 61%
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 62%
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.3 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.5 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.4 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.2 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:25.9
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.7 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.0 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.0 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.5 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.9 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.3 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.3 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.9 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.9 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.5 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.3 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.3 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.2 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.5 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 82%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 97%
#
# FPS:26.2 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 82%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 97%
#
# FPS:25.9 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.6 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.6 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.2 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.3 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.5 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.2 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.3 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.9 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.9 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.5 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.8 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.2 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.4 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.7 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.0 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.3 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.3 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.3 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.4 	 AVG_FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.8 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.8 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.8 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.0 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.8 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.0 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.0 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.8 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.0 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:24.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:24.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:24.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.0 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:24.8 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:24.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:24.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:23.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:23.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:23.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:23.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:24.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.5 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.4 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.2 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.7 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.0 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.3 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.8 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.9 	 AVG_FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.7 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.7 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 90%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:30.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.7 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 89%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 89%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:27.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.8 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:29.1 	 AVG_FPS:28.8
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.

# %% [markdown]
# #### <font color="blue">14.6 Scenario 6</font>
#
# A video of the crowd.  Variable ligth conditions.

# %%
# !./darknet/darknet detector demo $yolo_setup $yolo_test $yolo_best_weights FacialMaskDetector/test/test-video2.mp4 -thresh .6 2 -out_filename out-vid2.avi -dont_show
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 90%
# Mask: 100%
#
# FPS:28.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 91%
# Mask: 100%
#
# FPS:28.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 97%
# No-Mask: 67%
# Mask: 99%
#
# FPS:27.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 94%
# No-Mask: 92%
# Mask: 98%
#
# FPS:28.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 97%
# No-Mask: 60%
# Mask: 93%
#
# FPS:27.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 94%
# No-Mask: 77%
# Mask: 98%
#
# FPS:27.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 90%
# No-Mask: 89%
# Mask: 98%
#
# FPS:28.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 91%
# No-Mask: 88%
# Mask: 98%
#
# FPS:28.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 91%
# No-Mask: 75%
#
# FPS:28.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 91%
# No-Mask: 74%
# Mask: 87%
#
# FPS:28.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 73%
# Mask: 82%
#
# FPS:29.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 82%
# No-Mask: 74%
#
# FPS:29.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 80%
#
# FPS:29.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 80%
#
# FPS:29.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 66%
#
# FPS:28.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 94%
# No-Mask: 70%
#
# FPS:28.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 94%
# Mask: 82%
#
# FPS:27.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
#
# FPS:27.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
#
# FPS:27.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
#
# FPS:26.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 94%
#
# FPS:26.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 67%
#
# FPS:26.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 75%
#
# FPS:25.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 61%
# Mask: 91%
#
# FPS:25.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 93%
# Mask: 97%
#
# FPS:25.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
# Mask: 96%
#
# FPS:25.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
#
# FPS:26.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 88%
# Mask: 100%
#
# FPS:25.9 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
# Mask: 98%
#
# FPS:25.4 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
# Mask: 100%
#
# FPS:25.2 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 93%
# Mask: 100%
#
# FPS:25.0 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 94%
# Mask: 100%
#
# FPS:24.8 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 92%
# No-Mask: 62%
# No-Mask: 60%
# Mask: 100%
#
# FPS:24.7 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 93%
# No-Mask: 91%
# Mask: 100%
# Mask: 98%
#
# FPS:24.6 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 96%
# No-Mask: 91%
# Mask: 100%
# Mask: 70%
#
# FPS:24.5 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 81%
# No-Mask: 73%
# Mask: 100%
# Mask: 98%
#
# FPS:24.5 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 90%
# No-Mask: 79%
# Mask: 94%
# Mask: 93%
#
# FPS:23.9 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 89%
# No-Mask: 78%
# Mask: 94%
# Mask: 94%
#
# FPS:23.8 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 97%
# Mask: 96%
# Mask: 96%
#
# FPS:23.8 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 93%
# No-Mask: 90%
# Mask: 95%
# Mask: 67%
#
# FPS:24.0 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 92%
# No-Mask: 75%
# Mask: 98%
# Mask: 95%
#
# FPS:24.5 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 87%
# No-Mask: 84%
# Mask: 99%
# Mask: 92%
#
# FPS:24.7 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
# No-Mask: 90%
# Mask: 99%
# Mask: 96%
#
# FPS:24.6 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
# No-Mask: 89%
# Mask: 99%
# Mask: 96%
#
# FPS:24.5 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 85%
# No-Mask: 81%
# Mask: 99%
#
# FPS:24.2 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# No-Mask: 90%
# No-Mask: 81%
# Mask: 100%
# Mask: 97%
# Mask: 91%
#
# FPS:24.2 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 75%
# Mask: 99%
# Mask: 98%
# Mask: 94%
#
# FPS:24.2 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 77%
# Mask: 99%
# Mask: 92%
# Mask: 91%
#
# FPS:24.3 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 89%
# No-Mask: 64%
# Mask: 89%
# Mask: 79%
#
# FPS:24.2 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 89%
# No-Mask: 65%
# Mask: 90%
# Mask: 79%
# Mask: 61%
#
# FPS:24.1 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 79%
# Mask: 99%
# Mask: 91%
#
# FPS:23.9 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
#
# FPS:23.2 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
#
# FPS:23.3 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
#
# FPS:23.4 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 88%
# Mask: 100%
# Mask: 99%
#
# FPS:23.4 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 87%
# Mask: 100%
# Mask: 99%
#
# FPS:23.5 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 87%
# No-Mask: 65%
# Mask: 99%
#
# FPS:23.5 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 82%
# Mask: 100%
# Mask: 99%
#
# FPS:23.4 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 89%
# No-Mask: 76%
# No-Mask: 66%
# Mask: 99%
# Mask: 98%
#
# FPS:23.5 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 76%
# No-Mask: 61%
# Mask: 99%
# Mask: 88%
#
# FPS:23.6 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 83%
# Mask: 72%
#
# FPS:23.5 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 81%
# Mask: 67%
#
# FPS:23.5 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 87%
# No-Mask: 72%
# Mask: 84%
#
# FPS:23.6 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 81%
# Mask: 93%
#
# FPS:24.3 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 70%
# Mask: 97%
#
# FPS:24.1 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 61%
# Mask: 92%
# Mask: 82%
#
# FPS:24.6 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 92%
#
# FPS:24.5 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 62%
# Mask: 91%
#
# FPS:24.9 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 91%
#
# FPS:24.7 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 62%
# Mask: 82%
#
# FPS:25.1 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 77%
# Mask: 99%
# Mask: 73%
#
# FPS:24.9 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 91%
#
# FPS:25.3 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 94%
# No-Mask: 94%
# Mask: 98%
#
# FPS:25.1 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 96%
# No-Mask: 96%
# Mask: 97%
#
# FPS:25.5 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 96%
# Mask: 81%
#
# FPS:25.3 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 91%
# No-Mask: 75%
#
# FPS:25.9 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 97%
#
# FPS:25.8 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
#
# FPS:26.1 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 94%
#
# FPS:25.9 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 97%
#
# FPS:26.2 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
#
# FPS:25.9 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
#
# FPS:26.2 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
#
# FPS:26.0 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 83%
# No-Mask: 62%
#
# FPS:26.3 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 83%
#
# FPS:26.0 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 82%
#
# FPS:26.3 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 88%
#
# FPS:26.0 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 80%
#
# FPS:26.3 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
#
# FPS:25.9 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 85%
#
# FPS:26.2 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 71%
#
# FPS:25.9 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 65%
#
# FPS:26.2 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 94%
# Mask: 73%
#
# FPS:25.9 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 87%
#
# FPS:25.3 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 61%
#
# FPS:25.2 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 95%
#
# FPS:25.1 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
#
# FPS:24.9 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
#
# FPS:24.8 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
#
# FPS:24.6 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 83%
# No-Mask: 63%
#
# FPS:24.5 	 AVG_FPS:26.5
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 97%
# No-Mask: 71%
#
# FPS:24.0 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 93%
# No-Mask: 80%
#
# FPS:24.2 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 79%
# No-Mask: 62%
#
# FPS:24.4 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 81%
# No-Mask: 61%
#
# FPS:24.7 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 66%
#
# FPS:24.6 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 94%
# No-Mask: 72%
# No-Mask: 68%
#
# FPS:24.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 98%
# No-Mask: 83%
# No-Mask: 73%
#
# FPS:25.6 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 75%
#
# FPS:26.1 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 82%
#
# FPS:26.3 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 81%
#
# FPS:26.8 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 84%
#
# FPS:27.2 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 89%
#
# FPS:27.6 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 87%
# No-Mask: 78%
# No-Mask: 64%
#
# FPS:27.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 86%
# No-Mask: 80%
#
# FPS:28.0 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 83%
#
# FPS:27.6 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 84%
#
# FPS:27.4 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 82%
# No-Mask: 72%
#
# FPS:27.1 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 68%
#
# FPS:27.2 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 69%
# No-Mask: 68%
# Mask: 70%
#
# FPS:26.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# No-Mask: 87%
# No-Mask: 87%
# No-Mask: 64%
#
# FPS:26.8 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 92%
# No-Mask: 82%
#
# FPS:26.5 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 93%
# No-Mask: 84%
#
# FPS:26.4 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 80%
# No-Mask: 77%
# No-Mask: 70%
# No-Mask: 69%
# No-Mask: 63%
# Mask: 64%
#
# FPS:26.2 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 95%
# No-Mask: 92%
# No-Mask: 75%
# No-Mask: 68%
# Mask: 94%
#
# FPS:26.3 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 90%
# No-Mask: 70%
# Mask: 93%
#
# FPS:25.6 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 78%
# No-Mask: 76%
# No-Mask: 72%
# No-Mask: 62%
#
# FPS:25.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 96%
# No-Mask: 90%
# No-Mask: 86%
# No-Mask: 83%
# No-Mask: 81%
# Mask: 98%
#
# FPS:25.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 96%
# No-Mask: 91%
# No-Mask: 87%
# No-Mask: 86%
# No-Mask: 82%
# No-Mask: 61%
# Mask: 98%
#
# FPS:26.5 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 93%
# No-Mask: 93%
# No-Mask: 76%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 92%
# No-Mask: 65%
# Mask: 99%
#
# FPS:26.3 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 90%
# No-Mask: 86%
# No-Mask: 62%
# No-Mask: 62%
# Mask: 99%
#
# FPS:26.5 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 91%
# No-Mask: 85%
# No-Mask: 74%
# Mask: 97%
#
# FPS:26.6 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 97%
# No-Mask: 88%
# Mask: 97%
#
# FPS:26.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 97%
# No-Mask: 88%
# Mask: 97%
#
# FPS:26.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 97%
# No-Mask: 95%
# Mask: 81%
#
# FPS:27.4 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 98%
# No-Mask: 98%
# No-Mask: 90%
#
# FPS:27.7 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 83%
# No-Mask: 75%
# Mask: 70%
#
# FPS:27.5 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 95%
# No-Mask: 75%
# No-Mask: 72%
# Mask: 100%
#
# FPS:27.6 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 76%
# Mask: 100%
#
# FPS:27.8 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 76%
# Mask: 100%
#
# FPS:27.8 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 93%
# No-Mask: 91%
# No-Mask: 60%
# Mask: 100%
#
# FPS:27.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 95%
# No-Mask: 91%
# No-Mask: 63%
# Mask: 100%
#
# FPS:28.3 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 97%
# No-Mask: 89%
# No-Mask: 61%
# No-Mask: 61%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 89%
# No-Mask: 81%
# No-Mask: 79%
# Mask: 100%
#
# FPS:28.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 87%
# No-Mask: 74%
# No-Mask: 69%
# Mask: 100%
#
# FPS:29.2 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 91%
# No-Mask: 76%
# No-Mask: 61%
# Mask: 100%
#
# FPS:29.4 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 97%
# No-Mask: 90%
# Mask: 100%
#
# FPS:29.6 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 75%
# Mask: 100%
#
# FPS:29.7 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
#
# FPS:29.8 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 89%
# Mask: 100%
#
# FPS:30.0 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
#
# FPS:30.1 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 67%
# Mask: 100%
#
# FPS:29.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# Mask: 100%
#
# FPS:29.8 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 92%
# Mask: 100%
#
# FPS:29.6 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 89%
# No-Mask: 69%
# Mask: 100%
#
# FPS:29.5 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 73%
# No-Mask: 60%
# Mask: 100%
#
# FPS:29.4 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 85%
# No-Mask: 64%
# Mask: 100%
#
# FPS:29.4 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 85%
# No-Mask: 65%
# No-Mask: 64%
# Mask: 100%
#
# FPS:29.4 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 88%
# Mask: 100%
#
# FPS:29.5 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 95%
# No-Mask: 95%
# Mask: 100%
#
# FPS:29.3 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 96%
# No-Mask: 85%
# Mask: 100%
#
# FPS:29.0 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 96%
# No-Mask: 89%
# Mask: 100%
#
# FPS:29.2 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# Mask: 100%
#
# FPS:29.4 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 97%
# Mask: 100%
#
# FPS:29.6 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 89%
# Mask: 100%
#
# FPS:29.8 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
# Mask: 97%
# Mask: 67%
# Mask: 62%
#
# FPS:29.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 93%
# Mask: 70%
#
# FPS:30.1 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:30.2 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 64%
# Mask: 100%
# Mask: 100%
#
# FPS:30.4 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
# Mask: 100%
#
# FPS:29.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 60%
# Mask: 100%
# Mask: 100%
#
# FPS:30.1 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 88%
# Mask: 100%
# Mask: 100%
#
# FPS:30.2 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 85%
# Mask: 100%
# Mask: 99%
#
# FPS:30.3 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 95%
# No-Mask: 67%
# No-Mask: 62%
# No-Mask: 61%
# Mask: 100%
# Mask: 94%
#
# FPS:30.4 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 97%
# No-Mask: 69%
# No-Mask: 68%
# Mask: 100%
#
# FPS:30.5 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 97%
# No-Mask: 70%
# No-Mask: 70%
# Mask: 100%
#
# FPS:30.6 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 89%
# No-Mask: 88%
# No-Mask: 81%
# No-Mask: 61%
# Mask: 100%
#
# FPS:30.7 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 96%
# No-Mask: 86%
# No-Mask: 73%
# No-Mask: 68%
# Mask: 100%
#
# FPS:30.8 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 95%
# No-Mask: 89%
# No-Mask: 83%
# No-Mask: 61%
# No-Mask: 61%
# Mask: 100%
#
# FPS:30.8 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# No-Mask: 91%
# No-Mask: 89%
# No-Mask: 75%
# No-Mask: 72%
# Mask: 100%
#
# FPS:30.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 95%
# No-Mask: 95%
# No-Mask: 71%
# Mask: 98%
#
# FPS:31.0 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 96%
# No-Mask: 93%
# No-Mask: 71%
# Mask: 98%
#
# FPS:31.0 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 94%
# No-Mask: 91%
# Mask: 100%
#
# FPS:31.1 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 91%
# Mask: 100%
#
# FPS:30.9 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 97%
# No-Mask: 66%
# Mask: 100%
#
# FPS:30.7 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 67%
# Mask: 100%
# Mask: 71%
#
# FPS:30.5 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 71%
# Mask: 100%
# Mask: 62%
#
# FPS:30.3 	 AVG_FPS:24.2
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 69%
# Mask: 100%
# Mask: 64%
#
# FPS:29.9 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 93%
# No-Mask: 73%
# Mask: 100%
#
# FPS:29.8 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
#
# FPS:29.7 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 78%
# No-Mask: 68%
# Mask: 100%
#
# FPS:29.6 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 79%
# Mask: 100%
#
# FPS:29.9 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 88%
# No-Mask: 65%
# No-Mask: 63%
# Mask: 99%
#
# FPS:30.0 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 85%
# No-Mask: 68%
# No-Mask: 68%
# Mask: 99%
#
# FPS:30.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 95%
# No-Mask: 83%
# No-Mask: 64%
# Mask: 99%
#
# FPS:30.2 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 87%
# No-Mask: 81%
# No-Mask: 80%
#
# FPS:30.4 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 82%
# No-Mask: 70%
#
# FPS:30.4 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 91%
# No-Mask: 73%
#
# FPS:30.5 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 88%
# No-Mask: 85%
#
# FPS:30.6 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 87%
# No-Mask: 83%
#
# FPS:30.6 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 83%
# Mask: 89%
#
# FPS:30.7 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 69%
# Mask: 86%
#
# FPS:30.5 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 69%
# No-Mask: 61%
# Mask: 74%
# Mask: 62%
#
# FPS:30.0 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 85%
# Mask: 97%
# Mask: 91%
#
# FPS:30.2 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 91%
#
# FPS:30.4 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 94%
#
# FPS:30.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 74%
# Mask: 69%
#
# FPS:30.0 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 96%
# No-Mask: 79%
# No-Mask: 77%
# No-Mask: 70%
#
# FPS:29.9 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 85%
#
# FPS:29.5 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 61%
#
# FPS:29.6 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 70%
#
# FPS:29.9 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 72%
#
# FPS:30.0 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 71%
#
# FPS:30.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 61%
#
# FPS:30.3 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 79%
# No-Mask: 60%
#
# FPS:30.3 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
#
# FPS:30.5 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 95%
#
# FPS:30.5 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 96%
#
# FPS:30.6 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
#
# FPS:30.7 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 74%
#
# FPS:29.8 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 60%
# Mask: 81%
#
# FPS:29.5 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 96%
# No-Mask: 79%
# Mask: 79%
#
# FPS:29.4 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 89%
# Mask: 86%
#
# FPS:29.5 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 89%
# Mask: 86%
#
# FPS:29.7 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 68%
# Mask: 80%
#
# FPS:29.6 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 62%
# Mask: 80%
#
# FPS:29.2 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 89%
# Mask: 96%
#
# FPS:28.8 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 100%
# Mask: 99%
#
# FPS:28.6 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 64%
# Mask: 98%
#
# FPS:28.2 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 75%
# Mask: 98%
#
# FPS:28.2 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 67%
# Mask: 99%
#
# FPS:27.0 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 88%
# Mask: 99%
#
# FPS:27.2 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 96%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 89%
# Mask: 100%
#
# FPS:27.3 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 85%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 77%
# No-Mask: 65%
# No-Mask: 62%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
#
# FPS:26.9 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 90%
# Mask: 100%
#
# FPS:27.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 82%
# Mask: 100%
# Mask: 92%
#
# FPS:27.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 82%
# No-Mask: 74%
# Mask: 100%
# Mask: 99%
#
# FPS:27.2 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 86%
# No-Mask: 81%
# Mask: 100%
# Mask: 99%
#
# FPS:26.9 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 92%
# No-Mask: 86%
# No-Mask: 78%
# Mask: 100%
# Mask: 99%
#
# FPS:26.5 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 84%
# Mask: 100%
# Mask: 99%
#
# FPS:26.4 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 63%
# Mask: 100%
# Mask: 98%
#
# FPS:26.2 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 79%
# No-Mask: 63%
# Mask: 100%
# Mask: 99%
#
# FPS:26.3 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 89%
# No-Mask: 73%
# Mask: 100%
# Mask: 98%
#
# FPS:26.0 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 89%
# No-Mask: 67%
# Mask: 100%
# Mask: 98%
#
# FPS:25.8 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 88%
# No-Mask: 61%
# Mask: 100%
# Mask: 98%
#
# FPS:25.6 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 62%
# Mask: 100%
# Mask: 98%
#
# FPS:25.6 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 84%
# No-Mask: 62%
# Mask: 100%
# Mask: 99%
#
# FPS:25.5 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 87%
# No-Mask: 71%
# Mask: 100%
# Mask: 97%
#
# FPS:25.6 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 96%
# No-Mask: 92%
# No-Mask: 82%
# Mask: 100%
# Mask: 97%
#
# FPS:25.3 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 96%
# No-Mask: 94%
# No-Mask: 81%
# No-Mask: 61%
# Mask: 100%
# Mask: 97%
#
# FPS:25.3 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 93%
# No-Mask: 83%
# Mask: 100%
# Mask: 91%
#
# FPS:25.3 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 91%
# No-Mask: 87%
# Mask: 100%
# Mask: 78%
#
# FPS:25.4 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 99%
# Mask: 100%
# Mask: 89%
#
# FPS:25.3 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 97%
# No-Mask: 77%
# Mask: 100%
#
# FPS:25.4 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 90%
# No-Mask: 81%
# Mask: 100%
#
# FPS:25.3 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 97%
# No-Mask: 90%
# No-Mask: 79%
# Mask: 100%
#
# FPS:25.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 97%
# No-Mask: 71%
# No-Mask: 62%
# Mask: 100%
#
# FPS:25.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 95%
# No-Mask: 79%
# No-Mask: 70%
# Mask: 100%
#
# FPS:25.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 96%
# No-Mask: 96%
# No-Mask: 85%
# Mask: 100%
#
# FPS:25.0 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 96%
# No-Mask: 91%
# Mask: 100%
# Mask: 83%
#
# FPS:25.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 84%
# No-Mask: 71%
# No-Mask: 62%
# Mask: 100%
#
# FPS:25.2 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 84%
# No-Mask: 74%
# No-Mask: 63%
# Mask: 100%
#
# FPS:25.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 91%
# No-Mask: 83%
# No-Mask: 66%
# Mask: 100%
#
# FPS:25.1 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 78%
# Mask: 100%
#
# FPS:25.2 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# Mask: 100%
#
# FPS:25.2 	 AVG_FPS:28.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
# Mask: 100%
#
# FPS:25.1 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 67%
# Mask: 100%
#
# FPS:25.2 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 70%
# Mask: 100%
#
# FPS:25.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 66%
# Mask: 100%
#
# FPS:26.4 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 99%
#
# FPS:26.6 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 71%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 91%
#
# FPS:27.3 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 61%
# Mask: 100%
# Mask: 99%
#
# FPS:27.5 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 62%
# Mask: 100%
# Mask: 99%
#
# FPS:27.2 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 72%
# No-Mask: 61%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:27.0 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 78%
# No-Mask: 66%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 80%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:26.7 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 90%
# Mask: 100%
# Mask: 90%
#
# FPS:26.6 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 91%
# Mask: 100%
#
# FPS:26.5 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 91%
# Mask: 100%
#
# FPS:26.5 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 92%
# No-Mask: 85%
# Mask: 100%
#
# FPS:27.0 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 97%
# No-Mask: 76%
# Mask: 99%
#
# FPS:27.3 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# No-Mask: 89%
# No-Mask: 78%
# No-Mask: 72%
# Mask: 100%
# Mask: 94%
# Mask: 66%
#
# FPS:27.0 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 89%
# No-Mask: 88%
# No-Mask: 71%
# Mask: 100%
# Mask: 95%
# Mask: 80%
#
# FPS:27.2 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 82%
# No-Mask: 78%
# No-Mask: 74%
# No-Mask: 73%
# Mask: 100%
# Mask: 99%
#
# FPS:26.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 82%
# No-Mask: 81%
# No-Mask: 71%
# No-Mask: 63%
# Mask: 100%
# Mask: 99%
#
# FPS:27.0 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 93%
# No-Mask: 71%
# No-Mask: 68%
# Mask: 100%
# Mask: 99%
# Mask: 67%
#
# FPS:26.6 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 94%
# No-Mask: 70%
# No-Mask: 70%
# Mask: 100%
# Mask: 70%
#
# FPS:27.1 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 93%
# No-Mask: 89%
# No-Mask: 61%
# Mask: 99%
# Mask: 98%
#
# FPS:27.5 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 86%
# Mask: 100%
# Mask: 89%
#
# FPS:27.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 91%
# Mask: 100%
# Mask: 99%
#
# FPS:28.0 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 93%
# Mask: 100%
# Mask: 99%
#
# FPS:27.6 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 97%
# No-Mask: 73%
# No-Mask: 67%
# Mask: 100%
# Mask: 96%
#
# FPS:27.3 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 85%
# Mask: 100%
#
# FPS:27.5 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 94%
# Mask: 100%
#
# FPS:27.4 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 96%
# No-Mask: 88%
# No-Mask: 78%
# Mask: 100%
# Mask: 73%
#
# FPS:27.9 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 66%
# Mask: 99%
# Mask: 78%
#
# FPS:28.2 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 68%
# No-Mask: 65%
# Mask: 99%
# Mask: 75%
#
# FPS:27.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 95%
# No-Mask: 90%
# No-Mask: 87%
# No-Mask: 74%
# Mask: 100%
# Mask: 72%
#
# FPS:27.0 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 96%
# No-Mask: 96%
# Mask: 99%
# Mask: 82%
#
# FPS:27.1 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 96%
# No-Mask: 95%
# No-Mask: 81%
# Mask: 89%
#
# FPS:27.3 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 95%
# No-Mask: 66%
#
# FPS:27.4 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 97%
# No-Mask: 88%
# No-Mask: 74%
#
# FPS:27.5 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 97%
# No-Mask: 90%
# No-Mask: 69%
#
# FPS:27.7 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 84%
#
# FPS:27.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 90%
# No-Mask: 88%
# No-Mask: 72%
# No-Mask: 68%
#
# FPS:27.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 96%
# No-Mask: 89%
# No-Mask: 85%
# No-Mask: 61%
#
# FPS:27.9 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 93%
# No-Mask: 89%
# No-Mask: 83%
#
# FPS:27.2 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 92%
# No-Mask: 72%
#
# FPS:27.6 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 92%
# No-Mask: 72%
#
# FPS:27.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 95%
# No-Mask: 95%
# No-Mask: 62%
#
# FPS:27.9 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 96%
# No-Mask: 93%
# No-Mask: 92%
#
# FPS:27.9 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 97%
# No-Mask: 94%
# No-Mask: 89%
#
# FPS:28.0 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 95%
# No-Mask: 84%
#
# FPS:28.1 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 95%
# No-Mask: 94%
# No-Mask: 89%
# No-Mask: 66%
#
# FPS:28.2 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 96%
# No-Mask: 94%
# No-Mask: 91%
# No-Mask: 68%
#
# FPS:28.1 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 77%
# No-Mask: 72%
# No-Mask: 62%
#
# FPS:28.1 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 83%
#
# FPS:28.2 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 96%
# No-Mask: 72%
#
# FPS:28.2 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 87%
# No-Mask: 78%
#
# FPS:28.3 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 80%
#
# FPS:28.3 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 87%
#
# FPS:28.4 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 93%
#
# FPS:27.9 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 93%
# No-Mask: 90%
#
# FPS:27.9 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 95%
# No-Mask: 80%
#
# FPS:28.3 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# No-Mask: 88%
#
# FPS:28.5 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
#
# FPS:28.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
#
# FPS:29.0 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
#
# FPS:29.2 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
#
# FPS:29.4 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
#
# FPS:29.5 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 93%
# No-Mask: 89%
# No-Mask: 67%
#
# FPS:29.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
# No-Mask: 87%
# No-Mask: 86%
# Mask: 62%
#
# FPS:29.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 95%
# No-Mask: 87%
# No-Mask: 85%
# Mask: 68%
#
# FPS:30.0 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 94%
# No-Mask: 84%
# No-Mask: 79%
# Mask: 89%
# Mask: 87%
#
# FPS:30.1 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 94%
# Mask: 97%
#
# FPS:29.6 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 89%
# No-Mask: 74%
# No-Mask: 69%
# Mask: 97%
#
# FPS:29.0 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 72%
# Mask: 98%
# Mask: 93%
# Mask: 92%
#
# FPS:29.0 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 88%
# Mask: 97%
# Mask: 97%
# Mask: 96%
#
# FPS:28.6 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 89%
# Mask: 98%
# Mask: 97%
# Mask: 95%
#
# FPS:28.7 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
# No-Mask: 82%
# No-Mask: 71%
# Mask: 99%
# Mask: 98%
# Mask: 98%
#
# FPS:28.4 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 83%
# No-Mask: 74%
# Mask: 100%
# Mask: 100%
# Mask: 98%
#
# FPS:28.5 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 86%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:28.2 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 96%
#
# FPS:28.2 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 89%
# No-Mask: 84%
# Mask: 99%
# Mask: 99%
#
# FPS:27.9 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 87%
# No-Mask: 87%
# Mask: 100%
# Mask: 99%
#
# FPS:28.0 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 88%
# No-Mask: 72%
# Mask: 99%
# Mask: 99%
# Mask: 89%
#
# FPS:27.6 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 68%
# Mask: 100%
# Mask: 97%
# Mask: 77%
#
# FPS:27.8 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 85%
# No-Mask: 73%
# Mask: 100%
# Mask: 100%
# Mask: 97%
#
# FPS:27.4 	 AVG_FPS:27.1
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 86%
# Mask: 100%
# Mask: 98%
# Mask: 97%
#
# FPS:27.5 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 98%
#
# FPS:27.3 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 98%
#
# FPS:27.5 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 83%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:27.3 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 91%
# No-Mask: 84%
# Mask: 100%
# Mask: 93%
# Mask: 88%
#
# FPS:27.5 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 95%
# Mask: 100%
# Mask: 68%
#
# FPS:27.3 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
# No-Mask: 66%
# Mask: 100%
# Mask: 85%
#
# FPS:27.2 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 97%
# Mask: 74%
#
# FPS:27.1 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 97%
# Mask: 74%
#
# FPS:26.7 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
# Mask: 65%
#
# FPS:26.9 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 99%
# Mask: 99%
#
# FPS:26.5 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 98%
#
# FPS:26.7 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 98%
#
# FPS:26.5 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 99%
#
# FPS:26.7 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:27.1 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 72%
# Mask: 100%
# Mask: 100%
#
# FPS:27.5 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# Mask: 100%
# Mask: 98%
#
# FPS:27.9 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 99%
#
# FPS:28.1 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 89%
# No-Mask: 85%
# Mask: 99%
# Mask: 86%
#
# FPS:27.8 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 87%
# Mask: 100%
#
# FPS:27.7 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 89%
# Mask: 100%
#
# FPS:27.3 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 73%
# Mask: 100%
#
# FPS:27.7 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 84%
# Mask: 94%
#
# FPS:28.0 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 91%
# Mask: 93%
#
# FPS:28.3 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 87%
# Mask: 98%
# Mask: 91%
#
# FPS:28.4 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 90%
# Mask: 99%
# Mask: 97%
#
# FPS:28.1 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 91%
# Mask: 99%
# Mask: 96%
#
# FPS:28.1 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 92%
# Mask: 96%
#
# FPS:27.9 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 92%
# Mask: 99%
#
# FPS:28.1 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 95%
# Mask: 98%
#
# FPS:27.8 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 95%
# Mask: 90%
#
# FPS:27.1 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 89%
# No-Mask: 86%
#
# FPS:26.9 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 81%
#
# FPS:26.5 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# Mask: 91%
# Mask: 77%
#
# FPS:26.7 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 94%
# Mask: 95%
# Mask: 61%
#
# FPS:26.4 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 95%
# Mask: 94%
#
# FPS:26.8 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 97%
# Mask: 99%
# Mask: 88%
#
# FPS:27.3 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 86%
# No-Mask: 78%
# Mask: 79%
# Mask: 72%
#
# FPS:27.0 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 84%
# No-Mask: 77%
# Mask: 78%
# Mask: 71%
#
# FPS:26.7 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 93%
# No-Mask: 84%
# No-Mask: 62%
#
# FPS:26.6 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 79%
# No-Mask: 61%
#
# FPS:26.3 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 93%
# No-Mask: 71%
# No-Mask: 64%
#
# FPS:26.2 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 88%
# No-Mask: 73%
# Mask: 71%
#
# FPS:26.1 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 73%
# No-Mask: 69%
# Mask: 80%
# Mask: 71%
#
# FPS:26.0 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 73%
# No-Mask: 66%
# Mask: 79%
# Mask: 66%
#
# FPS:25.7 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 86%
# Mask: 63%
#
# FPS:25.6 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 92%
# No-Mask: 84%
#
# FPS:25.3 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 87%
# No-Mask: 68%
# Mask: 75%
#
# FPS:25.6 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 88%
# No-Mask: 65%
#
# FPS:25.8 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 91%
# No-Mask: 70%
# Mask: 77%
#
# FPS:25.8 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 91%
# No-Mask: 71%
# No-Mask: 60%
# Mask: 76%
#
# FPS:25.4 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 91%
# Mask: 91%
#
# FPS:25.7 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 85%
# No-Mask: 78%
# Mask: 94%
# Mask: 67%
#
# FPS:25.1 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 88%
# No-Mask: 67%
# Mask: 79%
#
# FPS:25.5 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 86%
# No-Mask: 83%
#
# FPS:25.5 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 90%
# No-Mask: 65%
#
# FPS:25.4 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 91%
# No-Mask: 65%
#
# FPS:25.2 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 74%
#
# FPS:25.5 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 85%
# No-Mask: 74%
#
# FPS:25.3 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 76%
#
# FPS:25.6 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 74%
# Mask: 68%
#
# FPS:25.5 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 68%
#
# FPS:25.9 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 65%
#
# FPS:26.2 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 95%
#
# FPS:26.4 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 88%
# No-Mask: 84%
# No-Mask: 71%
#
# FPS:26.6 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 88%
# No-Mask: 69%
#
# FPS:26.7 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 66%
# Mask: 98%
#
# FPS:26.6 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 78%
# Mask: 100%
# Mask: 70%
#
# FPS:26.7 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 79%
# Mask: 100%
# Mask: 69%
#
# FPS:26.9 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 87%
# Mask: 100%
# Mask: 86%
#
# FPS:27.1 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 68%
# Mask: 99%
#
# FPS:27.3 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
#
# FPS:27.4 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 90%
# Mask: 98%
# Mask: 85%
#
# FPS:27.6 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# Mask: 100%
# Mask: 99%
# Mask: 77%
#
# FPS:27.5 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 69%
# Mask: 100%
# Mask: 99%
# Mask: 76%
#
# FPS:27.7 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 72%
# Mask: 100%
# Mask: 98%
#
# FPS:27.8 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 87%
# Mask: 98%
# Mask: 95%
#
# FPS:27.8 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 82%
# Mask: 99%
# Mask: 68%
#
# FPS:27.9 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 75%
# No-Mask: 61%
# Mask: 77%
#
# FPS:28.0 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
#
# FPS:28.1 	 AVG_FPS:27.8
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
#
# FPS:28.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 94%
# No-Mask: 61%
# Mask: 81%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 62%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 96%
#
# FPS:27.7 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 66%
#
# FPS:27.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 92%
# Mask: 89%
#
# FPS:27.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 89%
# Mask: 90%
#
# FPS:27.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 93%
# Mask: 89%
#
# FPS:28.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 88%
# Mask: 97%
#
# FPS:28.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 89%
# No-Mask: 88%
#
# FPS:27.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# No-Mask: 74%
# Mask: 87%
#
# FPS:27.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 70%
# Mask: 93%
#
# FPS:28.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 67%
# Mask: 94%
#
# FPS:28.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 73%
# No-Mask: 67%
# Mask: 92%
# Mask: 92%
#
# FPS:28.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 99%
# No-Mask: 72%
# Mask: 92%
# Mask: 80%
#
# FPS:28.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# Mask: 97%
# Mask: 94%
#
# FPS:28.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 74%
# Mask: 99%
# Mask: 99%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 76%
# Mask: 99%
# Mask: 99%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 99%
# Mask: 86%
#
# FPS:28.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 99%
# Mask: 90%
#
# FPS:27.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 100%
# Mask: 97%
#
# FPS:28.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:28.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 98%
#
# FPS:28.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 98%
#
# FPS:28.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 100%
#
# FPS:28.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 100%
#
# FPS:28.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 100%
#
# FPS:28.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 100%
# Mask: 97%
# Mask: 70%
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# Mask: 100%
# Mask: 60%
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# Mask: 100%
# Mask: 61%
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 88%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 78%
# Mask: 100%
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 85%
# Mask: 100%
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 92%
# Mask: 100%
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 93%
# Mask: 100%
#
# FPS:27.8 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 98%
# Mask: 100%
#
# FPS:27.9 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# Mask: 100%
#
# FPS:28.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 86%
# Mask: 100%
#
# FPS:28.0 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 86%
# Mask: 100%
#
# FPS:28.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 82%
# Mask: 100%
#
# FPS:28.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 74%
# Mask: 100%
#
# FPS:28.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 91%
# No-Mask: 63%
# Mask: 100%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 72%
# Mask: 100%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 81%
# Mask: 100%
#
# FPS:28.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 82%
# Mask: 100%
#
# FPS:28.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 96%
# No-Mask: 81%
# Mask: 100%
#
# FPS:28.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 89%
# No-Mask: 82%
# Mask: 100%
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# No-Mask: 92%
# Mask: 100%
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 90%
# No-Mask: 88%
# Mask: 97%
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 92%
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
#
# FPS:28.1 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 78%
# No-Mask: 71%
# No-Mask: 63%
#
# FPS:28.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 94%
# No-Mask: 91%
# No-Mask: 89%
#
# FPS:28.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 93%
# No-Mask: 92%
# No-Mask: 89%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 93%
# No-Mask: 71%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 93%
# No-Mask: 71%
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 95%
# No-Mask: 94%
#
# FPS:28.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 95%
# No-Mask: 90%
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 96%
# No-Mask: 96%
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 91%
# No-Mask: 87%
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 91%
# No-Mask: 90%
#
# FPS:28.6 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 91%
# No-Mask: 91%
#
# FPS:28.5 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 95%
# No-Mask: 93%
#
# FPS:28.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 91%
# No-Mask: 87%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 98%
# No-Mask: 93%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 98%
# No-Mask: 81%
#
# FPS:28.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 96%
# No-Mask: 74%
#
# FPS:28.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 100%
# No-Mask: 96%
# No-Mask: 74%
#
# FPS:28.2 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 97%
# No-Mask: 96%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 96%
# No-Mask: 83%
#
# FPS:28.3 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 99%
# No-Mask: 99%
# No-Mask: 93%
# No-Mask: 65%
#
# FPS:28.4 	 AVG_FPS:26.6
#
#  cvWriteFrame
# Objects:
#
# No-Mask: 95%
# No-Mask: 94%
# No-Mask: 81%
# No-Mask: 80%
#
# FPS:28.4 	 AVG_FPS:26.6
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.

# %% [markdown]
# Finally move the video files to the output folder

# %%
# !cd /content/drive/My\ Drive/YOLO
# !mv out-vid1.avi FacialMaskDetector/result/yolov3
# !mv out-vid2.avi FacialMaskDetector/result/yolov3

# %% [markdown]
# ### <font color="blue">15. Conclusion</font>
#
# This concludes the yolo v3 training and inference google colab notebook.
#
# The disadvantage of GPU for large training datasets will leave you to wait the availability of free GPUs on the cloud (Colab).
#
# Anyway you could always start with the final weights and retrain over it, continuing with the last point of training.
